# %% [markdown]
# <a href="https://colab.research.google.com/github/maanpooja/hello-world/blob/master/SO_Tag_Predictor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <img src='images/pic1.jpg'/>

# %%
# !pip install -q scikit-multilearn
# Out:
#      |████████████████████████████████| 92kB 7.1MB/s

# %%
import warnings
warnings.filterwarnings("ignore")
import pandas as pd
import sqlite3
import csv
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from datetime import datetime
from wordcloud import WordCloud
import re
import os
from sqlalchemy import create_engine # database connection
import datetime as dt
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem.snowball import SnowballStemmer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.multiclass import OneVsRestClassifier
from sklearn.linear_model import SGDClassifier
from sklearn import metrics
from sklearn.metrics import f1_score,precision_score,recall_score
from sklearn import svm
from sklearn.linear_model import LogisticRegression
# from scikit-multilearn.adapt import mlknn
from skmultilearn.adapt import mlknn
from skmultilearn.problem_transform import ClassifierChain
from skmultilearn.problem_transform import BinaryRelevance
from skmultilearn.problem_transform import LabelPowerset
from sklearn.naive_bayes import GaussianNB

# %%
from google.colab import output
# output.eval_js('new Audio("http://mr-jat.in/files/download/type/64/id/1062").play()')

# %% [markdown]
# # Stack Overflow: Tag Prediction

# %% [markdown]
# <h1>1. Business Problem </h1>

# %% [markdown]
# <h2> 1.1 Description </h2>

# %% [markdown]
# <p style='font-size:18px'><b> Description </b></p>
# <p>
# Stack Overflow is the largest, most trusted online community for developers to learn, share their programming knowledge, and build their careers.<br />
# <br />
# Stack Overflow is something which every programmer use one way or another. Each month, over 50 million developers come to Stack Overflow to learn, share their knowledge, and build their careers. It features questions and answers on a wide range of topics in computer programming. The website serves as a platform for users to ask and answer questions, and, through membership and active participation, to vote questions and answers up or down and edit questions and answers in a fashion similar to a wiki or Digg. As of April 2014 Stack Overflow has over 4,000,000 registered users, and it exceeded 10,000,000 questions in late August 2015. Based on the type of tags assigned to questions, the top eight most discussed topics on the site are: Java, JavaScript, C#, PHP, Android, jQuery, Python and HTML.<br />
# <br />
# </p>

# %% [markdown]
# <p style='font-size:18px'><b> Problem Statemtent </b></p>
# Suggest the tags based on the content that was there in the question posted on Stackoverflow.

# %% [markdown]
# <p style='font-size:18px'><b> Source:  </b> https://www.kaggle.com/c/facebook-recruiting-iii-keyword-extraction/</p>

# %% [markdown]
# <h2> 1.2 Source / useful links </h2>

# %% [markdown]
# Data Source : https://www.kaggle.com/c/facebook-recruiting-iii-keyword-extraction/data <br>
# Youtube : https://youtu.be/nNDqbUhtIRg <br>
# Research paper : https://www.microsoft.com/en-us/research/wp-content/uploads/2016/02/tagging-1.pdf <br>
# Research paper : https://dl.acm.org/citation.cfm?id=2660970&dl=ACM&coll=DL

# %% [markdown]
# <h2> 1.3 Real World / Business Objectives and Constraints </h2>

# %% [markdown]
# 1. Predict as many tags as possible with high precision and recall.
# 2. Incorrect tags could impact customer experience on StackOverflow.
# 3. No strict latency constraints.

# %% [markdown]
# <h1>2. Machine Learning problem </h1>

# %% [markdown]
# <h2> 2.1 Data </h2>

# %% [markdown]
# <h3> 2.1.1 Data Overview </h3>

# %% [markdown]
# Refer: https://www.kaggle.com/c/facebook-recruiting-iii-keyword-extraction/data
# <br>
# All of the data is in 2 files: Train and Test.<br />
# <pre>
# <b>Train.csv</b> contains 4 columns: Id,Title,Body,Tags.<br />
# <b>Test.csv</b> contains the same columns but without the Tags, which you are to predict.<br />
# <b>Size of Train.csv</b> - 6.75GB<br />
# <b>Size of Test.csv</b> - 2GB<br />
# <b>Number of rows in Train.csv</b> = 6034195<br />
# </pre>
# The questions are randomized and contains a mix of verbose text sites as well as sites related to math and programming. The number of questions from each site may vary, and no filtering has been performed on the questions (such as closed questions).<br />
# <br />

# %% [markdown]
# __Data Field Explaination__
#
# Dataset contains 6,034,195 rows. The columns in the table are:<br />
# <pre>
# <b>Id</b> - Unique identifier for each question<br />
# <b>Title</b> - The question's title<br />
# <b>Body</b> - The body of the question<br />
# <b>Tags</b> - The tags associated with the question in a space-seperated format (all lowercase, should not contain tabs '\t' or ampersands '&')<br />
# </pre>
#
# <br />

# %% [markdown]
# <h3>2.1.2 Example Data point </h3>

# %% [markdown]
# <pre>
# <b>Title</b>:  Implementing Boundary Value Analysis of Software Testing in a C++ program?
# <b>Body </b>: <pre><code>
#         #include&lt;
#         iostream&gt;\n
#         #include&lt;
#         stdlib.h&gt;\n\n
#         using namespace std;\n\n
#         int main()\n
#         {\n
#                  int n,a[n],x,c,u[n],m[n],e[n][4];\n
#                  cout&lt;&lt;"Enter the number of variables";\n         cin&gt;&gt;n;\n\n
#                  cout&lt;&lt;"Enter the Lower, and Upper Limits of the variables";\n
#                  for(int y=1; y&lt;n+1; y++)\n
#                  {\n
#                     cin&gt;&gt;m[y];\n
#                     cin&gt;&gt;u[y];\n
#                  }\n
#                  for(x=1; x&lt;n+1; x++)\n
#                  {\n
#                     a[x] = (m[x] + u[x])/2;\n
#                  }\n
#                  c=(n*4)-4;\n
#                  for(int a1=1; a1&lt;n+1; a1++)\n
#                  {\n\n
#                     e[a1][0] = m[a1];\n
#                     e[a1][1] = m[a1]+1;\n
#                     e[a1][2] = u[a1]-1;\n
#                     e[a1][3] = u[a1];\n
#                  }\n
#                  for(int i=1; i&lt;n+1; i++)\n
#                  {\n
#                     for(int l=1; l&lt;=i; l++)\n
#                     {\n
#                         if(l!=1)\n
#                         {\n
#                             cout&lt;&lt;a[l]&lt;&lt;"\\t";\n
#                         }\n
#                     }\n
#                     for(int j=0; j&lt;4; j++)\n
#                     {\n
#                         cout&lt;&lt;e[i][j];\n
#                         for(int k=0; k&lt;n-(i+1); k++)\n
#                         {\n
#                             cout&lt;&lt;a[k]&lt;&lt;"\\t";\n
#                         }\n
#                         cout&lt;&lt;"\\n";\n
#                     }\n
#                  }    \n\n
#                  system("PAUSE");\n
#                  return 0;    \n
#         }\n
#         </code></pre>\n\n
#         <p>The answer should come in the form of a table like</p>\n\n
#         <pre><code>
#         1            50              50\n
#         2            50              50\n
#         99           50              50\n
#         100          50              50\n
#         50           1               50\n
#         50           2               50\n
#         50           99              50\n
#         50           100             50\n
#         50           50              1\n
#         50           50              2\n
#         50           50              99\n
#         50           50              100\n
#         </code></pre>\n\n
#         <p>if the no of inputs is 3 and their ranges are\n
#         1,100\n
#         1,100\n
#         1,100\n
#         (could be varied too)</p>\n\n
#         <p>The output is not coming,can anyone correct the code or tell me what\'s wrong?</p>\n'
# <b>Tags </b>: 'c++ c'
# </pre>

# %% [markdown]
# <h2>2.2 Mapping the real-world problem to a Machine Learning Problem </h2>

# %% [markdown]
# <h3> 2.2.1 Type of Machine Learning Problem </h3>

# %% [markdown]
# <p> It is a multi-label classification problem  <br>
# <b>Multi-label Classification</b>: Multilabel classification assigns to each sample a set of target labels. This can be thought as predicting properties of a data-point that are not mutually exclusive, such as topics that are relevant for a document. A question on Stackoverflow might be about any of C, Pointers, FileIO and/or memory-management at the same time or none of these. <br>
# __Credit__: http://scikit-learn.org/stable/modules/multiclass.html
# </p>

# %% [markdown]
# <h3>2.2.2 Performance metric </h3>

# %% [markdown]
# <b>Micro-Averaged F1-Score (Mean F Score) </b>:
# The F1 score can be interpreted as a weighted average of the precision and recall, where an F1 score reaches its best value at 1 and worst score at 0. The relative contribution of precision and recall to the F1 score are equal. The formula for the F1 score is:
#
# <i>F1 = 2 * (precision * recall) / (precision + recall)</i><br>
#
# In the multi-class and multi-label case, this is the weighted average of the F1 score of each class. <br>
#
# <b>'Micro f1 score': </b><br>
# Calculate metrics globally by counting the total true positives, false negatives and false positives. This is a better metric when we have class imbalance.
# <br>
#
# <b>'Macro f1 score': </b><br>
# Calculate metrics for each label, and find their unweighted mean. This does not take label imbalance into account.
# <br>
#
# https://www.kaggle.com/wiki/MeanFScore <br>
# http://scikit-learn.org/stable/modules/generated/sklearn.metrics.f1_score.html <br>
# <br>
# <b> Hamming loss </b>: The Hamming loss is the fraction of labels that are incorrectly predicted. <br>
# https://www.kaggle.com/wiki/HammingLoss <br>

# %% [markdown]
# <h1> 3. Exploratory Data Analysis </h1>

# %% [markdown]
# <h2> 3.1 Data Loading and Cleaning </h2>

# %% [markdown]
# <h3>3.1.1 Using Pandas with SQLite to Load the data</h3>

# %%
# Install the PyDrive wrapper & import libraries.
# This only needs to be done once per notebook.
# !pip install -U -q PyDrive
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

# Authenticate and create the PyDrive client.
# This only needs to be done once per notebook.
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# Download a file based on its file ID.
#
# A file ID looks like: laggVyWshwcyP6kEI-y_W3P8D26sz https://drive.google.com/open?id=
file_id = '13m2kiMbvGAT5yhZpP_NMhNmgfrFFX1vm'
downloaded = drive.CreateFile({'id': file_id})
downloaded.GetContentFile('Train.csv')
# print('Downloaded content "{}"'.format(downloaded.GetContentString()))
# Out:
#      |████████████████████████████████| 993kB 6.7MB/s
#   Building wheel for PyDrive (setup.py) ... done

# %%
#Creating db file from csv
#Learn SQL: https://www.w3schools.com/sql/default.asp
if not os.path.isfile('train.db'):
    start = datetime.now()
    disk_engine = create_engine('sqlite:///train.db')
#     start = dt.datetime.now()       //same as above datetime
    chunksize = 180000
    j = 0
    index_start = 1
    for df in pd.read_csv('/content/Train.csv', names=['Id', 'Title', 'Body', 'Tags'], chunksize=chunksize, iterator=True, encoding='utf-8', ):
        df.index += index_start               #RangeIndex(start=17690001, stop=17700001, step=1)
        j+=1
        print('{} rows'.format(j*chunksize))
        df.to_sql('data', disk_engine, if_exists='append')
        index_start = df.index[-1] + 1                              #17700001
    print("Time taken to run this cell :", datetime.now() - start)
# Out:
# 180000 rows
# 360000 rows
# 540000 rows
# 720000 rows
# 900000 rows
# 1080000 rows
# 1260000 rows
# 1440000 rows
# 1620000 rows
# 1800000 rows
# 1980000 rows
# 2160000 rows
# 2340000 rows
# 2520000 rows
# 2700000 rows
# 2880000 rows
# 3060000 rows
# 3240000 rows
# 3420000 rows
# 3600000 rows
# 3780000 rows
# 3960000 rows
# 4140000 rows
# 4320000 rows
# 4500000 rows
# 4680000 rows
# 4860000 rows
# 5040000 rows
# 5220000 rows
# 5400000 rows
# 5580000 rows
# 5760000 rows
# 5940000 rows
# 6120000 rows
# Time taken to run this cell : 0:03:29.457233

# %% [markdown]
# <h3> 3.1.2 Counting the number of rows </h3>

# %%
if os.path.isfile('train.db'):
    start = datetime.now()
    con = sqlite3.connect('train.db')
    num_rows = pd.read_sql_query("""SELECT count(*) FROM data""", con)
    #Always remember to close the database
    print("Number of rows in the database :","\n",num_rows['count(*)'].values[0])
    con.close()
    print("Time taken to count the number of rows :", datetime.now() - start)
else:
    print("Please download the train.db file from drive or run the above cell to genarate train.db file")
# Out:
# Number of rows in the database :
#  6034196
# Time taken to count the number of rows : 0:00:00.058812

# %%
print(num_rows)
print(num_rows['count(*)'].values[0])
# Out:
#    count(*)
# 0   6034196
# 6034196

# %% [markdown]
# <h3>3.1.3 Checking for duplicates </h3>

# %%
#Learn SQl: https://www.w3schools.com/sql/default.asp
if os.path.isfile('train.db'):
    start = datetime.now()
    con = sqlite3.connect('train.db')
    df_no_dup = pd.read_sql_query('SELECT Title, Body, Tags, COUNT(*) as cnt_dup FROM data GROUP BY Title, Body, Tags', con)
    con.close()
    print("Time taken to run this cell :", datetime.now() - start)
else:
    print("Please download the train.db file from drive or run the first to genarate train.db file")
# Out:
# Time taken to run this cell : 0:01:23.968616

# %%
df_no_dup.head()
# we can observe that there are duplicates
# Out:
#                                                Title  ... cnt_dup
# 0       Implementing Boundary Value Analysis of S...  ...       1
# 1           Dynamic Datagrid Binding in Silverlight?  ...       1
# 2           Dynamic Datagrid Binding in Silverlight?  ...       1
# 3      java.lang.NoClassDefFoundError: javax/serv...  ...       1
# 4      java.sql.SQLException:[Microsoft][ODBC Dri...  ...       2
#
# [5 rows x 4 columns]

# %%
df_no_dup.shape
# Out:
# (4206315, 4)

# %%
print("number of duplicate questions :", num_rows['count(*)'].values[0]- df_no_dup.shape[0], "(",(1-((df_no_dup.shape[0])/(num_rows['count(*)'].values[0])))*100,"% )")
# Out:
# number of duplicate questions : 1827881 ( 30.292038906260256 % )

# %%
# number of times each question appeared in our database
df_no_dup.cnt_dup.value_counts()
# Out:
# 1    2656284
# 2    1272336
# 3     277575
# 4         90
# 5         25
# 6          5
# Name: cnt_dup, dtype: int64

# %%
te = 'c++ c python'
len(te.split(" "))
# Out:
# 3

# %%
start = datetime.now()
df_no_dup.fillna('',inplace=True)
df_no_dup["tag_count"] = df_no_dup["Tags"].apply(lambda text: len(text.split(" ")))
# adding a new feature number of tags per question
print("Time taken to run this cell :", datetime.now() - start)
df_no_dup.head()
# Out:
# Time taken to run this cell : 0:00:05.211059
#                                                Title  ... tag_count
# 0       Implementing Boundary Value Analysis of S...  ...         2
# 1           Dynamic Datagrid Binding in Silverlight?  ...         3
# 2           Dynamic Datagrid Binding in Silverlight?  ...         4
# 3      java.lang.NoClassDefFoundError: javax/serv...  ...         2
# 4      java.sql.SQLException:[Microsoft][ODBC Dri...  ...         2
#
# [5 rows x 5 columns]

# %%
# distribution of number of tags per question
df_no_dup.tag_count.value_counts()
# Out:
# 3    1206157
# 2    1111706
# 4     814996
# 1     568298
# 5     505158
# Name: tag_count, dtype: int64

# %%
#Creating a new database with no duplicates
if not os.path.isfile('train_no_dup.db'):
    disk_dup = create_engine("sqlite:///train_no_dup.db")
    no_dup = pd.DataFrame(df_no_dup, columns=['Title', 'Body', 'Tags'])
    no_dup.to_sql('no_dup_train',disk_dup)

# %%
con = sqlite3.connect('train_no_dup.db')
x = pd.read_sql_query("""SELECT count(*) FROM no_dup_train""", con)
print(x)
con.close()
# Out:
#    count(*)
# 0   4206315

# %%
#This method seems more appropriate to work with this much data.
#creating the connection with database file.
if os.path.isfile('train_no_dup.db'):
    start = datetime.now()
    con = sqlite3.connect('train_no_dup.db')
    tag_data = pd.read_sql_query("""SELECT Tags FROM no_dup_train""", con)
    #Always remember to close the database
    con.close()

    print(tag_data.head())
    # Let's now drop unwanted column.
#     print(tag_data.columns[0])
#     tag_data.drop(tag_data.index[0], inplace=True)     #useless line
    #Printing first 5 columns from our data frame
#     print(tag_data.head())
    print("Time taken to run this cell :", datetime.now() - start)
else:
    print("Please download the train.db file from drive or run the above cells to genarate train.db file")
# Out:
#                                   Tags
# 0                                c++ c
# 1          c# silverlight data-binding
# 2  c# silverlight data-binding columns
# 3                             jsp jstl
# 4                            java jdbc
# Time taken to run this cell : 0:00:24.920966

# %%
tag_data.shape
# Out:
# (4206315, 1)

# %%
type(tag_data)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# <h2> 3.2 Analysis of Tags </h2>

# %% [markdown]
# <h3> 3.2.1 Total number of unique tags </h3>

# %%
# Importing & Initializing the "CountVectorizer" object, which
#is scikit-learn's bag of words tool.

#by default 'split()' will tokenize each tag using space.
vectorizer = CountVectorizer(tokenizer = lambda x: x.split())
# fit_transform() does two functions: First, it fits the model
# and learns the vocabulary; second, it transforms our training data
# into feature vectors. The input to fit_transform should be a list of strings.
tag_dtm = vectorizer.fit_transform(tag_data['Tags'])

# %%
type(tag_data['Tags'])
# print(tag_data['Tags'])
# Out:
# pandas.core.series.Series

# %%
print(tag_dtm.get_shape())
# Out:
# (4206315, 42048)

# %%
print(tag_dtm[4337])
# Out:
#   (0, 32207)	1
#   (0, 32393)	1
#   (0, 16999)	1
#   (0, 15166)	1

# %%
print("Number of data points :", tag_dtm.shape[0])
print("Number of unique tags :", tag_dtm.shape[1])
# Out:
# Number of data points : 4206315
# Number of unique tags : 42048

# %%
#'get_feature_name()' gives us the vocabulary.
tags = vectorizer.get_feature_names()
#Lets look at the tags we have.
print("Some of the tags we have :", tags[100:110])
# Out:
# Some of the tags we have : ['2010', '2013', '21cfr11', '24bit', '24hour', '256color', '2checkout', '2d', '2d-3d-conversion', '2d-array']

# %% [markdown]
# <h3> 3.2.3 Number of times a tag appeared </h3>

# %%
# https://stackoverflow.com/questions/15115765/how-to-access-sparse-matrix-elements
#Lets now store the document term matrix in a dictionary.
freqs = tag_dtm.sum(axis=0).A1
result = dict(zip(tags, freqs))

# %%
freqs.shape
# Out:
# (42048,)

# %%
#Saving this dictionary to csv files.
if not os.path.isfile('tag_counts_dict_dtm.csv'):
    with open('tag_counts_dict_dtm.csv', 'w') as csv_file:
        writer = csv.writer(csv_file)
        for key, value in result.items():
            writer.writerow([key, value])
tag_df = pd.read_csv("tag_counts_dict_dtm.csv", names=['Tags', 'Counts'])
tag_df.head()
# Out:
#             Tags  Counts
# 0             .a      18
# 1           .app      37
# 2   .asp.net-mvc       1
# 3      .aspxauth      21
# 4  .bash-profile     138

# %%
unsorted_tag_count = tag_df['Counts'].values

# %%
tag_df_sorted = tag_df.sort_values(['Counts'], ascending=False)
tag_counts = tag_df_sorted['Counts'].values

# %%
print(tag_df_sorted.shape)
tag_df_sorted.head()
# Out:
# (42048, 2)
#              Tags  Counts
# 4337           c#  331505
# 18069        java  299414
# 27249         php  284103
# 18157  javascript  265423
# 1234      android  235436

# %%
tag_counts
# Out:
# array([331505, 299414, 284103, ...,      1,      1,      1])

# %%
plt.plot(tag_counts)
plt.title("Distribution of number of times tag appeared questions")
plt.grid()
plt.xlabel("Tag number")
plt.ylabel("Number of times tag appeared")
plt.show()

# %%
plt.plot(tag_counts[0:10000])
plt.title('first 10k tags: Distribution of number of times tag appeared questions')
plt.grid()
plt.xlabel("Tag number")
plt.ylabel("Number of times tag appeared")
plt.show()
print(len(tag_counts[0:10000:25]), tag_counts[0:10000:25])    ##it is just giving 400 tag count with gap 25 tag count in between
# Out:
# 400 [331505  44829  22429  17728  13364  11162  10029   9148   8054   7151
#    6466   5865   5370   4983   4526   4281   4144   3929   3750   3593
#    3453   3299   3123   2986   2891   2738   2647   2527   2431   2331
#    2259   2186   2097   2020   1959   1900   1828   1770   1723   1673
#    1631   1574   1532   1479   1448   1406   1365   1328   1300   1266
#    1245   1222   1197   1181   1158   1139   1121   1101   1076   1056
#    1038   1023   1006    983    966    952    938    926    911    891
#     882    869    856    841    830    816    804    789    779    770
#     752    743    733    725    712    702    688    678    671    658
#     650    643    634    627    616    607    598    589    583    577
#     568    559    552    545    540    533    526    518    512    506
#     500    495    490    485    480    477    469    465    457    450
#     447    442    437    432    426    422    418    413    408    403
#     398    393    388    385    381    378    374    370    367    365
#     361    357    354    350    347    344    342    339    336    332
#     330    326    323    319    315    312    309    307    304    301
#     299    296    293    291    289    286    284    281    278    276
#     275    272    270    268    265    262    260    258    256    254
#     252    250    249    247    245    243    241    239    238    236
#     234    233    232    230    228    226    224    222    220    219
#     217    215    214    212    210    209    207    205    204    203
#     201    200    199    198    196    194    193    192    191    189
#     188    186    185    183    182    181    180    179    178    177
#     175    174    172    171    170    169    168    167    166    165
#     164    162    161    160    159    158    157    156    156    155
#     154    153    152    151    150    149    149    148    147    146
#     145    144    143    142    142    141    140    139    138    137
#     137    136    135    134    134    133    132    131    130    130
#     129    128    128    127    126    126    125    124    124    123
#     123    122    122    121    120    120    119    118    118    117
#     117    116    116    115    115    114    113    113    112    111
#     111    110    109    109    108    108    107    106    106    106
#     105    105    104    104    103    103    102    102    101    101
#     100    100     99     99     98     98     97     97     96     96
#      95     95     94     94     93     93     93     92     92     91
#      91     90     90     89     89     88     88     87     87     86
#      86     86     85     85     84     84     83     83     83     82
#      82     82     81     81     80     80     80     79     79     78
#      78     78     78     77     77     76     76     76     75     75
#      75     74     74     74     73     73     73     73     72     72]

# %%
plt.plot(tag_counts[0:1000])
plt.title('first 1k tags: Distribution of number of times tag appeared questions')
plt.grid()
plt.xlabel("Tag number")
plt.ylabel("Number of times tag appeared")
plt.show()
print(len(tag_counts[0:1000:5]), tag_counts[0:1000:5])
# Out:
# 200 [331505 221533 122769  95160  62023  44829  37170  31897  26925  24537
#   22429  21820  20957  19758  18905  17728  15533  15097  14884  13703
#   13364  13157  12407  11658  11228  11162  10863  10600  10350  10224
#   10029   9884   9719   9411   9252   9148   9040   8617   8361   8163
#    8054   7867   7702   7564   7274   7151   7052   6847   6656   6553
#    6466   6291   6183   6093   5971   5865   5760   5577   5490   5411
#    5370   5283   5207   5107   5066   4983   4891   4785   4658   4549
#    4526   4487   4429   4335   4310   4281   4239   4228   4195   4159
#    4144   4088   4050   4002   3957   3929   3874   3849   3818   3797
#    3750   3703   3685   3658   3615   3593   3564   3521   3505   3483
#    3453   3427   3396   3363   3326   3299   3272   3232   3196   3168
#    3123   3094   3073   3050   3012   2986   2983   2953   2934   2903
#    2891   2844   2819   2784   2754   2738   2726   2708   2681   2669
#    2647   2621   2604   2594   2556   2527   2510   2482   2460   2444
#    2431   2409   2395   2380   2363   2331   2312   2297   2290   2281
#    2259   2246   2222   2211   2198   2186   2162   2142   2132   2107
#    2097   2078   2057   2045   2036   2020   2011   1994   1971   1965
#    1959   1952   1940   1932   1912   1900   1879   1865   1855   1841
#    1828   1821   1813   1801   1782   1770   1760   1747   1741   1734
#    1723   1707   1697   1688   1683   1673   1665   1656   1646   1639]

# %%
plt.plot(tag_counts[0:500])
plt.title('first 500 tags: Distribution of number of times tag appeared questions')
plt.grid()
plt.xlabel("Tag number")
plt.ylabel("Number of times tag appeared")
plt.show()
print(len(tag_counts[0:500:5]), tag_counts[0:500:5])
# Out:
# 100 [331505 221533 122769  95160  62023  44829  37170  31897  26925  24537
#   22429  21820  20957  19758  18905  17728  15533  15097  14884  13703
#   13364  13157  12407  11658  11228  11162  10863  10600  10350  10224
#   10029   9884   9719   9411   9252   9148   9040   8617   8361   8163
#    8054   7867   7702   7564   7274   7151   7052   6847   6656   6553
#    6466   6291   6183   6093   5971   5865   5760   5577   5490   5411
#    5370   5283   5207   5107   5066   4983   4891   4785   4658   4549
#    4526   4487   4429   4335   4310   4281   4239   4228   4195   4159
#    4144   4088   4050   4002   3957   3929   3874   3849   3818   3797
#    3750   3703   3685   3658   3615   3593   3564   3521   3505   3483]

# %%
plt.plot(tag_counts[0:100], c='b')
plt.scatter(x=list(range(0,100,5)), y=tag_counts[0:100:5], c='orange', label="quantiles with 0.05 intervals")
# quantiles with 0.25 difference
plt.scatter(x=list(range(0,100,25)), y=tag_counts[0:100:25], c='m', label = "quantiles with 0.25 intervals")

for x,y in zip(list(range(0,100,25)), tag_counts[0:100:25]):
    plt.annotate(s="({} , {})".format(x,y), xy=(x,y), xytext=(x-0.05, y+500))

plt.title('first 100 tags: Distribution of number of times tag appeared questions')
plt.grid()
plt.xlabel("Tag number")
plt.ylabel("Number of times tag appeared")
plt.legend()
plt.show()
print(len(tag_counts[0:100:5]), tag_counts[0:100:5])
# Out:
# 20 [331505 221533 122769  95160  62023  44829  37170  31897  26925  24537
#   22429  21820  20957  19758  18905  17728  15533  15097  14884  13703]

# %%
# Store tags greater than 10K in one list
lst_tags_gt_10k = tag_df[tag_df.Counts>10000].Tags
#Print the length of the list
print ('{} Tags are used more than 10000 times'.format(len(lst_tags_gt_10k)))
# Store tags greater than 100K in one list
lst_tags_gt_100k = tag_df[tag_df.Counts>100000].Tags
#Print the length of the list.
print ('{} Tags are used more than 100000 times'.format(len(lst_tags_gt_100k)))
# Out:
# 153 Tags are used more than 10000 times
# 14 Tags are used more than 100000 times

# %% [markdown]
# <b>Observations:</b><br />
# 1. There are total 153 tags which are used more than 10000 times.
# 2. 14 tags are used more than 100000 times.
# 3. Most frequent tag (i.e. c#) is used 331505 times.
# 4. Since some tags occur much more frequenctly than others, Micro-averaged F1-score is the appropriate metric for this probelm.

# %% [markdown]
# <h3> 3.2.4 Tags Per Question </h3>

# %%
#Storing the count of tag in each question in list 'tag_count'
tag_quest_count = tag_dtm.sum(axis=1).tolist()
#Converting list of lists into single list, we will get [[3], [4], [2], [2], [3]] and we are converting this to [3, 4, 2, 2, 3]
tag_quest_count=[int(j) for i in tag_quest_count for j in i]
print ('We have total {} datapoints.'.format(len(tag_quest_count)))

print(tag_quest_count[:5])
# Out:
# We have total 4206315 datapoints.
# [2, 3, 4, 2, 2]

# %%
print( "Maximum number of tags per question: %d"%max(tag_quest_count))
print( "Minimum number of tags per question: %d"%min(tag_quest_count))
print( "Avg. number of tags per question: %f"% ((sum(tag_quest_count)*1.0)/len(tag_quest_count)))
# Out:
# Maximum number of tags per question: 5
# Minimum number of tags per question: 0
# Avg. number of tags per question: 2.899438

# %%
sns.countplot(tag_quest_count, palette='gist_rainbow')
plt.title("Number of tags in the questions ")
plt.xlabel("Number of Tags")
plt.ylabel("Number of questions")
plt.show()

# %% [markdown]
# <b>Observations:</b><br />
# 1. Maximum number of tags per question: 5
# 2. Minimum number of tags per question: 1
# 3. Avg. number of tags per question: 2.899
# 4. Most of the questions are having 2 or 3 tags

# %% [markdown]
# <h3>3.2.5 Most Frequent Tags </h3>

# %%
# Ploting word cloud
start = datetime.now()

# Lets first convert the 'result' dictionary to 'list of tuples'
tup = dict(result.items())
#Initializing WordCloud using frequencies of tags.
wordcloud = WordCloud(    background_color='black',
                          width=1600,
                          height=800,
                    ).generate_from_frequencies(tup)

fig = plt.figure(figsize=(30,20))
plt.imshow(wordcloud)
plt.axis('off')
plt.tight_layout(pad=0)
fig.savefig("tag.png")
plt.show()
print("Time taken to run this cell :", datetime.now() - start)
# Out:
# Time taken to run this cell : 0:00:04.135385

# %% [markdown]
# <b>Observations:</b><br />
# A look at the word cloud shows that "c#", "java", "php", "asp.net", "javascript", "c++" are some of the most frequent tags.

# %% [markdown]
# <h3> 3.2.6 The top 20 tags </h3>

# %%
i=np.arange(30)
tag_df_sorted.head(30).plot(kind='bar')
plt.title('Frequency of top 20 tags')
plt.xticks(i, tag_df_sorted['Tags'])
plt.xlabel('Tags')
plt.ylabel('Counts')
plt.show()

# %% [markdown]
# <b>Observations:</b><br />
# 1. Majority of the most frequent tags are programming language.
# 2. C# is the top most frequent programming language.
# 3. Android, IOS, Linux and windows are among the top most frequent operating systems.

# %% [markdown]
# <h3> 3.3 Cleaning and preprocessing of Questions </h3>

# %% [markdown]
# <h3> 3.3.1 Preprocessing </h3>

# %% [markdown]
# <ol>
#     <li> Sample 1M data points </li>
#     <li> Separate out code-snippets from Body </li>
#     <li> Remove Spcial characters from Question title and description (not in code)</li>
#     <li> Remove stop words (Except 'C') </li>
#     <li> Remove HTML Tags </li>
#     <li> Convert all the characters into small letters </li>
#     <li> Use SnowballStemmer to stem the words </li>
# </ol>

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
def striphtml(data):
    cleanr = re.compile('<.*?>')
    cleantext = re.sub(cleanr, ' ', str(data))
    return cleantext
stop_words = set(stopwords.words('english'))
stemmer = SnowballStemmer("english")

# %%
#http://www.sqlitetutorial.net/sqlite-python/create-tables/
# def create_connection(db_file):                                  EDITED
#     """ create a database connection to the SQLite database
#         specified by db_file
#     :param db_file: database file
#     :return: Connection object or None
#     """
#     try:
#         conn = sqlite3.connect(db_file)
#         return conn
#     except Error as e:
#         print(e)

#     return None

def create_table(conn, create_table_sql):
    """ create a table from the create_table_sql statement
    :param conn: Connection object
    :param create_table_sql: a CREATE TABLE statement
    :return:
    """
    try:
        c = conn.cursor()
        c.execute(create_table_sql)
    except Error as e:
        print(e)

def checkTableExists(dbcon):
    cursr = dbcon.cursor()
    str = "select name from sqlite_master where type='table'"
    table_names = cursr.execute(str)        ##<sqlite3.Cursor object at 0x7f3a422768f0>
    print("Tables in the databse:")
#     print(table_names)
    tables =table_names.fetchall()
    print(tables)
#     print(tables[0][0])
#     print(len(tables))
    return(len(tables))

def create_database_table(database, query):
#     conn = create_connection(database)      #edited
    conn = sqlite3.connect(database)
    if conn is not None:
        create_table(conn, query)
        checkTableExists(conn)
    else:
        print("Error! cannot create the database connection.")
    conn.close()

# %%
sql_create_table = """CREATE TABLE IF NOT EXISTS QuestionsProcessed (question text NOT NULL, code text, tags text, words_pre integer, words_post integer, is_code integer);"""
create_database_table("Processed.db", sql_create_table)
# Out:
# Tables in the databse:

# %%
con = sqlite3.connect('Processed.db')           ##testing
x = pd.read_sql_query("""SELECT * FROM QuestionsProcessed""", con)
con.close()
x
# Out:
# Empty DataFrame
# Columns: [question, code, tags, words_pre, words_post, is_code]
# Index: []

# %%
# http://www.sqlitetutorial.net/sqlite-delete/
# https://stackoverflow.com/questions/2279706/select-random-row-from-a-sqlite-table
start = datetime.now()
read_db = 'train_no_dup.db'
write_db = 'Processed.db'
if os.path.isfile(read_db):
#     conn_r = create_connection(read_db)
    conn_r = sqlite3.connect(read_db)

    if conn_r is not None:
        reader =conn_r.cursor()
        reader.execute("SELECT Title, Body, Tags From no_dup_train ORDER BY RANDOM() LIMIT 1000000;")

if os.path.isfile(write_db):
    conn_w = sqlite3.connect(write_db)
    if conn_w is not None:
        tables = checkTableExists(conn_w)
        writer =conn_w.cursor()
        if tables != 0:
            writer.execute("DELETE FROM QuestionsProcessed WHERE 1")
            print("Cleared All the rows")
print("Time taken to run this cell :", datetime.now() - start)
# Out:
# Tables in the databse:
# Cleared All the rows
# Time taken to run this cell : 0:07:45.427403

# %%
con = sqlite3.connect('train_no_dup.db')           ##testing
x = pd.read_sql_query("""SELECT count(*) FROM no_dup_train""", con)
con.close()
x
# Out:
#    count(*)
# 0   4206315

# %%
reader.fetchone()
print(reader)
# Out:
# <sqlite3.Cursor object at 0x7f441c02f730>

# %% [markdown]
# __ we create a new data base to store the sampled and preprocessed questions __

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
#http://www.bernzilla.com/2008/05/13/selecting-a-random-row-from-an-sqlite-table/

start = datetime.now()
preprocessed_data_list=[]
reader.fetchone()
questions_with_code=0
len_pre=0
len_post=0
questions_proccesed = 0
for row in reader:

    is_code = 0

    title, question, tags = row[0], row[1], row[2]

    if '<code>' in question:
        questions_with_code+=1
        is_code = 1
    x = len(question)+len(title)
    len_pre+=x

    code = str(re.findall(r'<code>(.*?)</code>', question, flags=re.DOTALL))

    question=re.sub('<code>(.*?)</code>', '', question, flags=re.MULTILINE|re.DOTALL)
    question=striphtml(question.encode('utf-8'))

    title=title.encode('utf-8')

    question=str(title)+" "+str(question)
    question=re.sub(r'[^A-Za-z]+',' ',question)
    words=word_tokenize(str(question.lower()))

    #Removing all single letter and and stopwords from question exceptt for the letter 'c'
    question=' '.join(str(stemmer.stem(j)) for j in words if j not in stop_words and (len(j)!=1 or j=='c'))

    len_post+=len(question)
    tup = (question,code,tags,x,len(question),is_code)
    questions_proccesed += 1
    writer.execute("insert into QuestionsProcessed(question,code,tags,words_pre,words_post,is_code) values (?,?,?,?,?,?)",tup)
    if (questions_proccesed%100000==0):
        print("number of questions completed=",questions_proccesed)

no_dup_avg_len_pre=(len_pre*1.0)/questions_proccesed
no_dup_avg_len_post=(len_post*1.0)/questions_proccesed

print( "Avg. length of questions(Title+Body) before processing: %d"%no_dup_avg_len_pre)
print( "Avg. length of questions(Title+Body) after processing: %d"%no_dup_avg_len_post)
print ("Percent of questions containing code: %d"%((questions_with_code*100.0)/questions_proccesed))

print("Time taken to run this cell :", datetime.now() - start)
# Out:
# number of questions completed= 100000
# number of questions completed= 200000
# number of questions completed= 300000
# number of questions completed= 400000
# number of questions completed= 500000
# number of questions completed= 600000
# number of questions completed= 700000
# number of questions completed= 800000
# number of questions completed= 900000
# Avg. length of questions(Title+Body) before processing: 1173
# Avg. length of questions(Title+Body) after processing: 327
# Percent of questions containing code: 57
# Time taken to run this cell : 0:25:48.060494

# %%
# dont forget to close the connections, or else you will end up with locks
conn_r.commit()
conn_w.commit()
conn_r.close()
conn_w.close()

# %%
if os.path.isfile(write_db):
    conn_r = sqlite3.connect(write_db)
    if conn_r is not None:
        reader =conn_r.cursor()
        reader.execute("SELECT question From QuestionsProcessed LIMIT 5")
        print("Questions after preprocessed")
        print('='*100)
        reader.fetchone()
        for row in reader:
            print(row)
            print('-'*100)
conn_r.commit()
conn_r.close()
# Out:
# Questions after preprocessed
# ====================================================================================================
# ('error miss core name path solr use queri solr index program sinc receiv error whenev go http localhost solr admin press search queri string error http status miss solr core name path type status report messag miss solr core name path descript request sent client syntact incorrect miss solr core name path apach tomcat',)
# ----------------------------------------------------------------------------------------------------
# ('get session sign usernam tri get usernam sign wont work check tri get error notic undefin index usernam know variabl name also tri wont work either error sign databas',)
# ----------------------------------------------------------------------------------------------------
# ('font color html email gmail know use inlin css style anyth html email notic odd overrid occur gmail tri chang color text tabl row open email gmail font famili black color overwrot gmail style see via firebug purpl color use instead black want font famili default arial san serif anyon know way safe overrid style gmail forc updat chang color non black color c color chang correct font famili still stuck arial',)
# ----------------------------------------------------------------------------------------------------
# ('sqlite databas squirrel relat sqlite databas connect littl part sql creat code mani mani connect destin log entri tabl see defin relationship foreign key db firefox addin sqlite manag set connect sql tab follow key pragma foreign key problem nbecaus good complex sql queri write design queri graphic tool decis squirrel download jdbc driver sqlite squirrel send tabl graph see relat queri builder tool anybodi experi sqlite squirrel combo exist altern queri design tool sqlite simplest way run sql creator script access exampl design queri',)
# ----------------------------------------------------------------------------------------------------

# %%
#Taking 1 Million entries to a dataframe.
write_db = 'Processed.db'
if os.path.isfile(write_db):
    conn_r = sqlite3.connect(write_db)
    if conn_r is not None:
        preprocessed_data = pd.read_sql_query("""SELECT question, Tags FROM QuestionsProcessed""", conn_r)
conn_r.commit()
conn_r.close()

# %%
preprocessed_data.head()
# Out:
#                                             question                             tags
# 0  asset outsid activ need open ad asset file cla...  android activity context assets
# 1  php nginx error win get error messag nginx ws ...                php windows nginx
# 2  run extra command get openvpn load proper open...       linux openvpn ubuntu-10.10
# 3  resiz gif anim save gif phone display devic wo...               android resize gif
# 4  get ariti method javascript exampl get ariti n...        objective-c introspection

# %%
print("number of data points in sample :", preprocessed_data.shape[0])
print("number of dimensions :", preprocessed_data.shape[1])
# Out:
# number of data points in sample : 999999
# number of dimensions : 2

# %%
# sql_create_table = """CREATE TABLE IF NOT EXISTS QuestionsProcessed1 (question text NOT NULL, code text, tags text, words_pre integer, words_post integer, is_code integer);"""
# create_database_table("Processed1.db", sql_create_table)

start = datetime.now()
read_db = 'train_no_dup.db'

if os.path.isfile(read_db):
    conn_r = sqlite3.connect(read_db)
    if conn_r is not None:
        reader =conn_r.cursor()
        reader.execute("SELECT Title, Body, Tags From no_dup_train ORDER BY RANDOM() LIMIT 10;")


#http://www.bernzilla.com/2008/05/13/selecting-a-random-row-from-an-sqlite-table/

start = datetime.now()
preprocessed_data_list=[]
reader.fetchone()
questions_with_code=0
len_pre=0
len_post=0
questions_proccesed = 0
for row in reader:

    is_code = 0

    title, question, tags = row[0], row[1], row[2]
    print("Title: " + title)
    print("Question: " + question)
    print("Tags: " + tags)
    print("**********Processing***********")

    if '<code>' in question:
        questions_with_code+=1
        is_code = 1
    x = len(question)+len(title)
    len_pre+=x

    code = str(re.findall(r'<code>(.*?)</code>', question, flags=re.DOTALL))
    print("Code: " + code)

    question=re.sub('<code>(.*?)</code>', '', question, flags=re.MULTILINE|re.DOTALL)
    print("**Question Procesing**")
    print("Step1: "+question)

    question=striphtml(question.encode('utf-8'))
    print("Step2: "+question)


    title=title.encode('utf-8')

    question=str(title)+" "+str(question)
    print("Step3: "+question)
    question=re.sub(r'[^A-Za-z]+',' ',question)
    print("Step4: "+question)
    words=word_tokenize(str(question.lower()))

    #Removing all single letter and and stopwords from question exceptt for the letter 'c'
    question=' '.join(str(stemmer.stem(j)) for j in words if j not in stop_words and (len(j)!=1 or j=='c'))
    print("Step5: "+question)
    len_post+=len(question)
    tup = (question,code,tags,x,len(question),is_code)
    print("****Processing Done*******")
    print("Result: ")
    print(tup)

print("Time taken to run this cell :", datetime.now() - start)
# Out:
# Tables in the databse:
# [('QuestionsProcessed1',)]
# Tables in the databse:
# [('QuestionsProcessed1',)]
# Cleared All the rows
# Time taken to run this cell : 0:00:07.984692
# Title: Remote Access over the Network to a Virtual Box Machine
# Question: <p>I am trying to remotely access a machine on Virtual Box, which is on a terminal server, but I don't want to have to log onto the terminal server first.</p>
#
# <p>I have enabled the Remote Display Settings in Virtual Box Manager.</p>
#
# <p><img src="http://i.stack.imgur.com/ndAtb.jpg" alt="Virtual Box Remote Display Settings"></p>
#
# <p>The firewall on the Virtual Machine is not blocking access, as I can ping the machine from my local machine, and from the terminal server.</p>
#
# <p>The issue is when I try to RDP into the machine, it asks me for the username and password, which I give the correct information, but says it fails to connect.</p>
#
# <p>Is this just my issue, or am I doing something wrong?</p>
#
# Tags: virtualbox virtual-machine remote-desktop
# **********Processing***********
# Code: []
# **Question Procesing**
# Step1: <p>I am trying to remotely access a machine on Virtual Box, which is on a terminal server, but I don't want to have to log onto the terminal server first.</p>
#
# <p>I have enabled the Remote Display Settings in Virtual Box Manager.</p>
#
# <p><img src="http://i.stack.imgur.com/ndAtb.jpg" alt="Virtual Box Remote Display Settings"></p>
#
# <p>The firewall on the Virtual Machine is not blocking access, as I can ping the machine from my local machine, and from the terminal server.</p>
#
# <p>The issue is when I try to RDP into the machine, it asks me for the username and password, which I give the correct information, but says it fails to connect.</p>
#
# <p>Is this just my issue, or am I doing something wrong?</p>
#
# Step2: b' I am trying to remotely access a machine on Virtual Box, which is on a terminal server, but I don\'t want to have to log onto the terminal server first. \n\n I have enabled the Remote Display Settings in Virtual Box Manager. \n\n   \n\n The firewall on the Virtual Machine is not blocking access, as I can ping the machine from my local machine, and from the terminal server. \n\n The issue is when I try to RDP into the machine, it asks me for the username and password, which I give the correct information, but says it fails to connect. \n\n Is this just my issue, or am I doing something wrong? \n'
# Step3: b'Remote Access over the Network to a Virtual Box Machine' b' I am trying to remotely access a machine on Virtual Box, which is on a terminal server, but I don\'t want to have to log onto the terminal server first. \n\n I have enabled the Remote Display Settings in Virtual Box Manager. \n\n   \n\n The firewall on the Virtual Machine is not blocking access, as I can ping the machine from my local machine, and from the terminal server. \n\n The issue is when I try to RDP into the machine, it asks me for the username and password, which I give the correct information, but says it fails to connect. \n\n Is this just my issue, or am I doing something wrong? \n'
# Step4: b Remote Access over the Network to a Virtual Box Machine b I am trying to remotely access a machine on Virtual Box which is on a terminal server but I don t want to have to log onto the terminal server first n n I have enabled the Remote Display Settings in Virtual Box Manager n n n n The firewall on the Virtual Machine is not blocking access as I can ping the machine from my local machine and from the terminal server n n The issue is when I try to RDP into the machine it asks me for the username and password which I give the correct information but says it fails to connect n n Is this just my issue or am I doing something wrong n
# Step5: remot access network virtual box machin tri remot access machin virtual box termin server want log onto termin server first enabl remot display set virtual box manag firewal virtual machin block access ping machin local machin termin server issu tri rdp machin ask usernam password give correct inform say fail connect issu someth wrong
# ****Processing Done*******
# Result:
# ('remot access network virtual box machin tri remot access machin virtual box termin server want log onto termin server first enabl remot display set virtual box manag firewal virtual machin block access ping machin local machin termin server issu tri rdp machin ask usernam password give correct inform say fail connect issu someth wrong', '[]', 'virtualbox virtual-machine remote-desktop', 762, 336, 0)
# number of questions completed= 1
# Title: Dual Space of Convergent Sequences
# Question: <p>For every linear functional $T$ on the space of convergent sequences in $\mathbb{R}$, how can I show it can be expressed $T(\{s_{n}\}) = \sum_{n \in \mathbb{N}} s_{n}T(e_{n})$ where $e_{n}$ are the canonical basis sequences?</p>
#
# Tags: functional-analysis banach-spaces
# **********Processing***********
# Code: []
# **Question Procesing**
# Step1: <p>For every linear functional $T$ on the space of convergent sequences in $\mathbb{R}$, how can I show it can be expressed $T(\{s_{n}\}) = \sum_{n \in \mathbb{N}} s_{n}T(e_{n})$ where $e_{n}$ are the canonical basis sequences?</p>
#
# Step2: b' For every linear functional $T$ on the space of convergent sequences in $\\mathbb{R}$, how can I show it can be expressed $T(\\{s_{n}\\}) = \\sum_{n \\in \\mathbb{N}} s_{n}T(e_{n})$ where $e_{n}$ are the canonical basis sequences? \n'
# Step3: b'Dual Space of Convergent Sequences' b' For every linear functional $T$ on the space of convergent sequences in $\\mathbb{R}$, how can I show it can be expressed $T(\\{s_{n}\\}) = \\sum_{n \\in \\mathbb{N}} s_{n}T(e_{n})$ where $e_{n}$ are the canonical basis sequences? \n'
# Step4: b Dual Space of Convergent Sequences b For every linear functional T on the space of convergent sequences in mathbb R how can I show it can be expressed T s n sum n in mathbb N s n T e n where e n are the canonical basis sequences n
# Step5: dual space converg sequenc everi linear function space converg sequenc mathbb show express sum mathbb canon basi sequenc
# ****Processing Done*******
# Result:
# ('dual space converg sequenc everi linear function space converg sequenc mathbb show express sum mathbb canon basi sequenc', '[]', 'functional-analysis banach-spaces', 266, 120, 0)
# number of questions completed= 2
# Title: How do I hide/show a div container within an unordered list so it replaces the inline list element
# Question: <p><strong>Before I begin, you should know there's a lot of information here. This one because I can't post pix yet, and two so we don't waste each other's time. All help I receive on this post is greatly appreciated!</strong></p>
#
# <p>So I'm working with an unordered list, where the list elements are displayed as inline in large text. The list itself takes up about 80% of the page.</p>
#
# <p>When you click a list element, a div should pop up to replace the list element explaining what the list element means, and if you click the div, the div disappears and the list element reappears.</p>
#
# <p>The problem I'm running into is that I want the div elements to replace the list element exactly how it's placed (margins and everything) in the unordered list. Instead what's happening is the div appears on the left everytime, and the unordered list elements get rearranged on the right.</p>
#
# <p><strong>Here's the html:</strong></p>
#
# <pre><code>    &lt;div id="bottom"&gt;
#     &lt;h1 class="issue_line"&gt;So what's the issue in Niagara Falls?&lt;/h1&gt;
#     &lt;ul class="issue_headings"&gt;
#     &lt;li class="issue1"&gt;Education&lt;/li&gt;
#  &lt;div class="quarter-box1"&gt;
#   &lt;p&gt;The members of NOAH recognize that &lt;strong&gt;quality education&lt;/strong&gt; is
#       necessary for any community to thrive...&lt;br/&gt;
#   &lt;a href="issues_taskforces.html"&gt;Read more.&lt;/a&gt;&lt;/p&gt;
#  &lt;/div&gt;
#
#     &lt;li class="issue2"&gt;Local Hiring&lt;/li&gt;
#  &lt;div class="quarter-box2"&gt;
#   &lt;p&gt;The need for jobs in Niagara County is overwhelming, and NOAH is working to
#       create more local jobs through the policy level...&lt;br/&gt;
#   &lt;a href="issues_taskforces.html"&gt;Read more.&lt;/a&gt;&lt;/p&gt;
#  &lt;/div&gt;
#
#     &lt;li class="issue3"&gt;Economic Development&lt;/li&gt;
#  &lt;div class="quarter-box3"&gt;
#   &lt;p&gt;Lorem ipsum dolor sit amet, consectetur adipiscing elit. Suspendisse et
#       facilisis risus. Quisque a gravida urna. Ut leo ligula...&lt;br/&gt;
#  &lt;a href="issues_taskforces.html"&gt;Read more.&lt;/a&gt;&lt;/p&gt;
#  &lt;/div&gt;
#
#     &lt;li class="issue4"&gt;Trasnportation&lt;/li&gt;
#  &lt;div class="quarter-box4"&gt;
#  &lt;p&gt;Lorem ipsum dolor sit amet, consectetur adipiscing elit. Suspendisse et
#      facilisis risus. Quisque a gravida urna. Ut leo ligula...&lt;br/&gt;
#  &lt;a href="issues_taskforces.html"&gt;Read more.&lt;/a&gt;&lt;/p&gt;
# &lt;/div&gt;
#
#     &lt;/ul&gt;
#     &lt;/div&gt;
# </code></pre>
#
# <p><strong>Here's the CSS</strong></p>
#
# <pre><code>     #bottom {
#       position: relative;
#       width: 100%;
#       margin: 0 auto;
#       clear: both;
#       padding-top: 5px;
#       padding-bottom: 5px;
#      }
#
#      ul.issue_headings {
#       width: 1498px;
#       float: left;
#       margin-top: 50px;
#       margin-bottom: 50px;
#       padding: 0;
#       list-style-type: none;
#       display: none;
#       text-align: center;
#      }
#
#      ul.issue_headings li {
#       display: inline;
#       margin-left: 2%;
#       padding: 0;
#       font-size: 3em;
#       color: #9ac0e2;
#      }
#
#      ul.issue_headings li:hover {
#       color: #FF9933;
#      }
#
#      .quarter-box1 {
#       float: left;
#       margin-left: 50px;
#       background-color: rgba(255, 255, 255, .9);
#       border: 3px solid #0c69bf;
#       box-shadow: 5px 5px 20px black;
#       width: 280px;
#       height: 150px;
#       overflow: hidden;
#       display: none;
#      }
#
#      .quarter-box2 {
#       float: left;
#       margin-left: 100px;
#       background-color: rgba(255, 255, 255, .9);
#       border: 3px solid #0c69bf;
#       box-shadow: 5px 5px 20px black;
#       width: 280px;
#       height: 150px;
#       overflow: hidden;
#       display: none;
#      }
#
#      .quarter-box3 {
#       float: left;
#       margin-left: 150px;
#       background-color: rgba(255, 255, 255, .9);
#       border: 3px solid #0c69bf;
#       box-shadow: 5px 5px 20px black;
#       width: 280px;
#       height: 150px;
#       overflow: hidden;
#       display: none;
#      }
#
#      .quarter-box4 {
#       float: left;
#       margin-left: 200px;
#       background-color: rgba(255, 255, 255, .9);
#       border: 3px solid #0c69bf;
#       box-shadow: 5px 5px 20px black;
#       width: 280px;
#       height: 150px;
#       overflow: hidden;
#       display: none;
#      }
#
#      .quarter-box1:hover, .quarter-box2:hover,.quarter-box3:hover, .quarter-box4:hover {
#       border: 3px solid #FF9933;
#      }
# </code></pre>
#
# <p><strong>Here's the jQuery</strong></p>
#
# <pre><code>        $('h1.issue_line').click(function(){
#           $('h1.issue_line').hide("slow");
#           $('ul.issue_headings').show("slow");
#           $('div.quarter-box1,div.quarter-box2,div.quarter-box3,div.quarter-
#      box4').hide("slow");
#         });
#         $('ul.issue_headings li.issue1').click(function(){
#           $('ul.issue_headings li.issue1,div.quarter-box2,div.quarter-box3,div.quarter-
#
#      box4').hide("slow");
#           $('div.quarter-box1,ul.issue_headings li.issue2,ul.issue_headings
#      li.issue3,ul.issue_headings li.issue4').show("slow");
#         });
#         $('ul.issue_headings li.issue2').click(function(){
#           $('ul.issue_headings li.issue2,div.quarter-box1,div.quarter-box3,div.quarter-
#      box4').hide("slow");
#           $('div.quarter-box2,ul.issue_headings li.issue1,ul.issue_headings
#      li.issue3,ul.issue_headings li.issue4').show("slow");
#         });
#         $('ul.issue_headings li.issue3').click(function(){
#         $('ul.issue_headings li.issue3,div.quarter-box1,div.quarter-box2,div.quarter-
#      box4').hide("slow");
#           $('div.quarter-box3,ul.issue_headings li.issue1,ul.issue_headings
#      li.issue2,ul.issue_headings li.issue4').show("slow");
#         });
#         $('ul.issue_headings li.issue4').click(function(){
#           $('ul.issue_headings li.issue4,div.quarter-box1,div.quarter-box2,div.quarter-
#      box3').hide("slow");
#           $('div.quarter-box4,ul.issue_headings li.issue1,ul.issue_headings
#      li.issue2,ul.issue_headings li.issue3').show("slow");
#         });
#         $('div.quarter-box1').click(function(){
#           $('div.quarter-box1').hide("slow");
#           $('ul.issue_headings li.issue1').show("slow");
#         });
#       $('div.quarter-box2').click(function(){
#           $('div.quarter-box2').hide("slow");
#           $('ul.issue_headings li.issue2').show("slow");
#         });
#       $('div.quarter-box3').click(function(){
#           $('div.quarter-box3').hide("slow");
#           $('ul.issue_headings li.issue3').show("slow");
#         });
#       $('div.quarter-box4').click(function(){
#           $('div.quarter-box4').hide("slow");
#           $('ul.issue_headings li.issue4').show("slow");
#         });
# </code></pre>
#
# <p><strong>Lemme know what you think!</strong></p>
#
# Tags: jquery list div hide show
# **********Processing***********
# Code: ['    &lt;div id="bottom"&gt;\n    &lt;h1 class="issue_line"&gt;So what\'s the issue in Niagara Falls?&lt;/h1&gt;\n    &lt;ul class="issue_headings"&gt;\n    &lt;li class="issue1"&gt;Education&lt;/li&gt;\n &lt;div class="quarter-box1"&gt;\n  &lt;p&gt;The members of NOAH recognize that &lt;strong&gt;quality education&lt;/strong&gt; is      \n      necessary for any community to thrive...&lt;br/&gt;\n  &lt;a href="issues_taskforces.html"&gt;Read more.&lt;/a&gt;&lt;/p&gt;\n &lt;/div&gt;\n\n    &lt;li class="issue2"&gt;Local Hiring&lt;/li&gt;\n &lt;div class="quarter-box2"&gt;\n  &lt;p&gt;The need for jobs in Niagara County is overwhelming, and NOAH is working to \n      create more local jobs through the policy level...&lt;br/&gt;\n  &lt;a href="issues_taskforces.html"&gt;Read more.&lt;/a&gt;&lt;/p&gt;\n &lt;/div&gt;\n\n    &lt;li class="issue3"&gt;Economic Development&lt;/li&gt;\n &lt;div class="quarter-box3"&gt;\n  &lt;p&gt;Lorem ipsum dolor sit amet, consectetur adipiscing elit. Suspendisse et   \n      facilisis risus. Quisque a gravida urna. Ut leo ligula...&lt;br/&gt;\n &lt;a href="issues_taskforces.html"&gt;Read more.&lt;/a&gt;&lt;/p&gt;\n &lt;/div&gt;\n\n    &lt;li class="issue4"&gt;Trasnportation&lt;/li&gt;\n &lt;div class="quarter-box4"&gt;\n &lt;p&gt;Lorem ipsum dolor sit amet, consectetur adipiscing elit. Suspendisse et \n     facilisis risus. Quisque a gravida urna. Ut leo ligula...&lt;br/&gt;\n &lt;a href="issues_taskforces.html"&gt;Read more.&lt;/a&gt;&lt;/p&gt;\n&lt;/div&gt;\n\n    &lt;/ul&gt;\n    &lt;/div&gt;\n', '     #bottom {\n      position: relative;\n      width: 100%;\n      margin: 0 auto; \n      clear: both;\n      padding-top: 5px;\n      padding-bottom: 5px;\n     }\n\n     ul.issue_headings {\n      width: 1498px;\n      float: left;\n      margin-top: 50px;\n      margin-bottom: 50px;\n      padding: 0;\n      list-style-type: none;\n      display: none;\n      text-align: center;\n     }\n\n     ul.issue_headings li {\n      display: inline;\n      margin-left: 2%;\n      padding: 0;\n      font-size: 3em;\n      color: #9ac0e2;\n     }\n\n     ul.issue_headings li:hover {\n      color: #FF9933;\n     }\n\n     .quarter-box1 { \n      float: left;\n      margin-left: 50px;\n      background-color: rgba(255, 255, 255, .9);\n      border: 3px solid #0c69bf;\n      box-shadow: 5px 5px 20px black;\n      width: 280px;\n      height: 150px;\n      overflow: hidden;\n      display: none;\n     }\n\n     .quarter-box2 { \n      float: left;\n      margin-left: 100px;\n      background-color: rgba(255, 255, 255, .9);\n      border: 3px solid #0c69bf;\n      box-shadow: 5px 5px 20px black;\n      width: 280px;\n      height: 150px;\n      overflow: hidden;\n      display: none;\n     }\n\n     .quarter-box3 {\n      float: left;\n      margin-left: 150px;\n      background-color: rgba(255, 255, 255, .9);\n      border: 3px solid #0c69bf;\n      box-shadow: 5px 5px 20px black;\n      width: 280px;\n      height: 150px;\n      overflow: hidden;\n      display: none;\n     } \n\n     .quarter-box4 {\n      float: left;\n      margin-left: 200px;\n      background-color: rgba(255, 255, 255, .9);\n      border: 3px solid #0c69bf;\n      box-shadow: 5px 5px 20px black;\n      width: 280px;\n      height: 150px;\n      overflow: hidden;\n      display: none;\n     }\n\n     .quarter-box1:hover, .quarter-box2:hover,.quarter-box3:hover, .quarter-box4:hover { \n      border: 3px solid #FF9933;\n     }\n', '        $(\'h1.issue_line\').click(function(){\n          $(\'h1.issue_line\').hide("slow");\n          $(\'ul.issue_headings\').show("slow");\n          $(\'div.quarter-box1,div.quarter-box2,div.quarter-box3,div.quarter-                 \n     box4\').hide("slow");\n        });\n        $(\'ul.issue_headings li.issue1\').click(function(){\n          $(\'ul.issue_headings li.issue1,div.quarter-box2,div.quarter-box3,div.quarter-\n\n     box4\').hide("slow");\n          $(\'div.quarter-box1,ul.issue_headings l ...
# **Question Procesing**
# Step1: <p><strong>Before I begin, you should know there's a lot of information here. This one because I can't post pix yet, and two so we don't waste each other's time. All help I receive on this post is greatly appreciated!</strong></p>
#
# <p>So I'm working with an unordered list, where the list elements are displayed as inline in large text. The list itself takes up about 80% of the page.</p>
#
# <p>When you click a list element, a div should pop up to replace the list element explaining what the list element means, and if you click the div, the div disappears and the list element reappears.</p>
#
# <p>The problem I'm running into is that I want the div elements to replace the list element exactly how it's placed (margins and everything) in the unordered list. Instead what's happening is the div appears on the left everytime, and the unordered list elements get rearranged on the right.</p>
#
# <p><strong>Here's the html:</strong></p>
#
# <pre></pre>
#
# <p><strong>Here's the CSS</strong></p>
#
# <pre></pre>
#
# <p><strong>Here's the jQuery</strong></p>
#
# <pre></pre>
#
# <p><strong>Lemme know what you think!</strong></p>
#
# Step2: b"  Before I begin, you should know there's a lot of information here. This one because I can't post pix yet, and two so we don't waste each other's time. All help I receive on this post is greatly appreciated!  \n\n So I'm working with an unordered list, where the list elements are displayed as inline in large text. The list itself takes up about 80% of the page. \n\n When you click a list element, a div should pop up to replace the list element explaining what the list element means, and if you click the div, the div disappears and the list element reappears. \n\n The problem I'm running into is that I want the div elements to replace the list element exactly how it's placed (margins and everything) in the unordered list. Instead what's happening is the div appears on the left everytime, and the unordered list elements get rearranged on the right. \n\n  Here's the html:  \n\n  \n\n  Here's the CSS  \n\n  \n\n  Here's the jQuery  \n\n  \n\n  Lemme know what you think!  \n"
# Step3: b'How do I hide/show a div container within an unordered list so it replaces the inline list element' b"  Before I begin, you should know there's a lot of information here. This one because I can't post pix yet, and two so we don't waste each other's time. All help I receive on this post is greatly appreciated!  \n\n So I'm working with an unordered list, where the list elements are displayed as inline in large text. The list itself takes up about 80% of the page. \n\n When you click a list element, a div should pop up to replace the list element explaining what the list element means, and if you click the div, the div disappears and the list element reappears. \n\n The problem I'm running into is that I want the div elements to replace the list element exactly how it's placed (margins and everything) in the unordered list. Instead what's happening is the div appears on the left everytime, and the unordered list elements get rearranged on the right. \n\n  Here's the html:  \n\n  \n\n  Here's the CSS  \n\n  \n\n  Here's the jQuery  \n\n  \n\n  Lemme know what you think!  \n"
# Step4: b How do I hide show a div container within an unordered list so it replaces the inline list element b Before I begin you should know there s a lot of information here This one because I can t post pix yet and two so we don t waste each other s time All help I receive on this post is greatly appreciated n n So I m working with an unordered list where the list elements are displayed as inline in large text The list itself takes up about of the page n n When you click a list element a div should pop up to replace the list element explaining what the list element means and if you click the div the div disappears and the list element reappears n n The problem I m running into is that I want the div elements to replace the list element exactly how it s placed margins and everything in the unordered list Instead what s happening is the div appears on the left everytime and the unordered list elements get rearranged on the right n n Here s the html n n n n Here s the CSS n n n n Here s the jQuery n n n n Lemme know what you think n
# Step5: hide show div contain within unord list replac inlin list element begin know lot inform one post pix yet two wast time help receiv post great appreci work unord list list element display inlin larg text list take page click list element div pop replac list element explain list element mean click div div disappear list element reappear problem run want div element replac list element exact place margin everyth unord list instead happen div appear left everytim unord list element get rearrang right html css jqueri lem know think
# ****Processing Done*******
# Result:
# ('hide show div contain within unord list replac inlin list element begin know lot inform one post pix yet two wast time help receiv post great appreci work unord list list element display inlin larg text list take page click list element div pop replac list element explain list element mean click div div disappear list element reappear problem run want div element replac list element exact place margin everyth unord list instead happen div appear left everytim unord list element get rearrang right html css jqueri lem know think', '[\'    &lt;div id="bottom"&gt;\\n    &lt;h1 class="issue_line"&gt;So what\\\'s the issue in Niagara Falls?&lt;/h1&gt;\\n    &lt;ul class="issue_headings"&gt;\\n    &lt;li class="issue1"&gt;Education&lt;/li&gt;\\n &lt;div class="quarter-box1"&gt;\\n  &lt;p&gt;The members of NOAH recognize that &lt;strong&gt;quality education&lt;/strong&gt; is      \\n      necessary for any community to thrive...&lt;br/&gt;\\n  &lt;a href="issues_taskforces.html"&gt;Read more.&lt;/a&gt;&lt;/p&gt;\\n &lt;/div&gt;\\n\\n    &lt;li class="issue2"&gt;Local Hiring&lt;/li&gt;\\n &lt;div class="quarter-box2"&gt;\\n  &lt;p&gt;The need for jobs in Niagara County is overwhelming, and NOAH is working to \\n      create more local jobs through the policy level...&lt;br/&gt;\\n  &lt;a href="issues_taskforces.html"&gt;Read more.&lt;/a&gt;&lt;/p&gt;\\n &lt;/div&gt;\\n\\n    &lt;li class="issue3"&gt;Economic Development&lt;/li&gt;\\n &lt;div class="quarter-box3"&gt;\\n  &lt;p&gt;Lorem ipsum dolor sit amet, consectetur adipiscing elit. Suspendisse et   \\n      facilisis risus. Quisque a gravida urna. Ut leo ligula...&lt;br/&gt;\\n &lt;a href="issues_taskforces.html"&gt;Read more.&lt;/a&gt;&lt;/p&gt;\\n &lt;/div&gt;\\n\\n    &lt;li class="issue4"&gt;Trasnportation&lt;/li&gt;\\n &lt;div class="quarter-box4"&gt;\\n &lt;p&gt;Lorem ipsum dolor sit amet, consectetur adipiscing elit. Suspendisse et \\n     facilisis risus. Quisque a gravida urna. Ut leo ligula...&lt;br/&gt;\\n &lt;a href="issues_taskforces.html"&gt;Read more.&lt;/a&gt;&lt;/p&gt;\\n&lt;/div&gt;\\n\\n    &lt;/ul&gt;\\n    &lt;/div&gt;\\n\', \'     #bottom {\\n      position: relative;\\n      width: 100%;\\n      margin: 0 auto; \\n      clear: both;\\n      padding-top: 5px;\\n      padding-bottom: 5px;\\n     }\\n\\n     ul.issue_headings {\\n      width: 1498px;\\n      float: left;\\n      margin-top: 50px;\\n      margin-bottom: 50px;\\n      padding: 0;\\n      list-style-type: none;\\n      display: none;\\n      text-align: center;\\n     }\\n\\n     ul.issue_headings li {\\n      display: inline;\\n      margin-left: 2%;\\n      padding: 0;\\n      font-size: 3em;\\n      color: #9ac0e2;\\n     }\\n\\n     ul.issue_headings li:hover {\\n      color: #FF9933;\\n     }\\n\\n     .quarter-box1 { \\n      float: left;\\n      margin-left: 50px;\\n      background-color: rgba(255, 255, 255, .9);\\n      border: 3px solid #0c69bf;\\n      box-shadow: 5px 5px 20px black;\\n      width: 280px;\\n      height: 150px;\\n      overflow: hidden;\\n      display: none;\\n     }\\n\\n     .quarter-box2 { \\n      float: left;\\n      margin-left: 100px;\\n      background-color: rgba(255, 255, 255, .9);\\n      border: 3px solid #0c69bf;\\n      box-shadow: 5px 5px 20px black;\\n      width: 280px;\\n      height: 150px;\\n      overflow: hidden;\\n      display: none;\\n     }\\n\\n     .quarter-box3 {\\n      float: left;\\n      margin-left: 150px;\\n      background-color: rgba(255, 255, 255, .9);\\n      border: 3px solid #0c69bf;\\n      box-shadow: 5px 5px 20px black;\\n      width: 280px;\\n      height: 150px;\\n      overflow: hidden;\\n      display: none;\\n     } \\n\\n     .quarter-box4 {\\n      float: left;\\n      margin-left: 200px;\\n      background-color: rgba(255, 255, 255, .9);\\n      border: 3px solid #0c69bf;\\n      box-shadow: 5px 5px 20px black;\\n      width: 280px;\\n      height: 150px;\\n      overflow: hidden;\\n      display: none;\\n     }\\n\\n ...
# number of questions completed= 3
# Title: JavaScript split function not working in IE
# Question: <p>I am using the split function in JavaScript.  It  works fine in Firefox and Chrome, but IE displays an error when I call the split function.  Is there a way to use other function like split?</p>
#
# Tags: javascript internet-explorer
# **********Processing***********
# Code: []
# **Question Procesing**
# Step1: <p>I am using the split function in JavaScript.  It  works fine in Firefox and Chrome, but IE displays an error when I call the split function.  Is there a way to use other function like split?</p>
#
# Step2: b' I am using the split function in JavaScript.  It  works fine in Firefox and Chrome, but IE displays an error when I call the split function.  Is there a way to use other function like split? \n'
# Step3: b'JavaScript split function not working in IE' b' I am using the split function in JavaScript.  It  works fine in Firefox and Chrome, but IE displays an error when I call the split function.  Is there a way to use other function like split? \n'
# Step4: b JavaScript split function not working in IE b I am using the split function in JavaScript It works fine in Firefox and Chrome but IE displays an error when I call the split function Is there a way to use other function like split n
# Step5: javascript split function work ie use split function javascript work fine firefox chrome ie display error call split function way use function like split
# ****Processing Done*******
# Result:
# ('javascript split function work ie use split function javascript work fine firefox chrome ie display error call split function way use function like split', '[]', 'javascript internet-explorer', 241, 153, 0)
# number of questions completed= 4
# Title: Doing Mathematical calulations in Order by with Linq
# Question: <p>I am quite new to Linq to Entity and having some trouble.</p>
#
# <p>Here's my Search repository:</p>
#
# <pre><code> public static List&lt;Centre&gt; Search(Search search)
#  {
#     using (var context = new MeetingRoomsContext())
#     {
#         var query = context.Centres
#                 .Include("Geo")
#                 .OrderBy( NEED HELP WITH THIS PART )
#
#         return query.ToList();
#     }
#  }
# </code></pre>
#
# <p>I am getting a search object which contains co-ordinates like this:</p>
#
# <pre><code>Search.LongLat = "(-6.265275, 53.334442)"
# </code></pre>
#
# <p>I need to break that out and do some maths against the co-ordinates in the DB in order to order results by the closest to the searched point for first.</p>
#
# <p>In mathematical terms it would be pythagoras:</p>
#
# <pre><code>squareRootOf((difference in latitude * difference in latitude) +
#              (difference in longitude * difference in longitude))
# </code></pre>
#
# <p>Really haven't a clue how to do this. Any help appreciated greatly</p>
#
# Tags: linq linq-to-entities
# **********Processing***********
# Code: [' public static List&lt;Centre&gt; Search(Search search)\n {\n    using (var context = new MeetingRoomsContext())\n    {\n        var query = context.Centres\n                .Include("Geo")\n                .OrderBy( NEED HELP WITH THIS PART )\n\n        return query.ToList();\n    }\n }\n', 'Search.LongLat = "(-6.265275, 53.334442)"\n', 'squareRootOf((difference in latitude * difference in latitude) + \n             (difference in longitude * difference in longitude))\n']
# **Question Procesing**
# Step1: <p>I am quite new to Linq to Entity and having some trouble.</p>
#
# <p>Here's my Search repository:</p>
#
# <pre></pre>
#
# <p>I am getting a search object which contains co-ordinates like this:</p>
#
# <pre></pre>
#
# <p>I need to break that out and do some maths against the co-ordinates in the DB in order to order results by the closest to the searched point for first.</p>
#
# <p>In mathematical terms it would be pythagoras:</p>
#
# <pre></pre>
#
# <p>Really haven't a clue how to do this. Any help appreciated greatly</p>
#
# Step2: b" I am quite new to Linq to Entity and having some trouble. \n\n Here's my Search repository: \n\n  \n\n I am getting a search object which contains co-ordinates like this: \n\n  \n\n I need to break that out and do some maths against the co-ordinates in the DB in order to order results by the closest to the searched point for first. \n\n In mathematical terms it would be pythagoras: \n\n  \n\n Really haven't a clue how to do this. Any help appreciated greatly \n"
# Step3: b'Doing Mathematical calulations in Order by with Linq' b" I am quite new to Linq to Entity and having some trouble. \n\n Here's my Search repository: \n\n  \n\n I am getting a search object which contains co-ordinates like this: \n\n  \n\n I need to break that out and do some maths against the co-ordinates in the DB in order to order results by the closest to the searched point for first. \n\n In mathematical terms it would be pythagoras: \n\n  \n\n Really haven't a clue how to do this. Any help appreciated greatly \n"
# Step4: b Doing Mathematical calulations in Order by with Linq b I am quite new to Linq to Entity and having some trouble n n Here s my Search repository n n n n I am getting a search object which contains co ordinates like this n n n n I need to break that out and do some maths against the co ordinates in the DB in order to order results by the closest to the searched point for first n n In mathematical terms it would be pythagoras n n n n Really haven t a clue how to do this Any help appreciated greatly n
# Step5: mathemat calul order linq quit new linq entiti troubl search repositori get search object contain co ordin like need break math co ordin db order order result closest search point first mathemat term would pythagora realli clue help appreci great
# ****Processing Done*******
# Result:
# ('mathemat calul order linq quit new linq entiti troubl search repositori get search object contain co ordin like need break math co ordin db order order result closest search point first mathemat term would pythagora realli clue help appreci great', '[\' public static List&lt;Centre&gt; Search(Search search)\\n {\\n    using (var context = new MeetingRoomsContext())\\n    {\\n        var query = context.Centres\\n                .Include("Geo")\\n                .OrderBy( NEED HELP WITH THIS PART )\\n\\n        return query.ToList();\\n    }\\n }\\n\', \'Search.LongLat = "(-6.265275, 53.334442)"\\n\', \'squareRootOf((difference in latitude * difference in latitude) + \\n             (difference in longitude * difference in longitude))\\n\']', 'linq linq-to-entities', 1050, 246, 1)
# number of questions completed= 5
# Title: Creating GameObject of variable size using Chingu
# Question: <p>I'm trying to make a GameObject which does not use Gosu::Image but Chingu::Rect.
# That's my class by omitting all unimportant methods</p>
#
# <pre><code>class Tile &lt; Chingu::GameObject
#   trait :bounding_box
#   trait :collision_detection
#
#   def initialize (x, y, w, h, opts={})
#     super opts
#     @area = Chingu::Rect.new(x,y,w,h)
#   end
#
#   def collision_at?(x, y)
#     @area.collide_point?(x,y)
#   end
# end
# </code></pre>
#
# <p>However collision detection is not working. Does anybody know how to tell the bounding_box to use a specific Rectangle and not an Image?</p>
#
# Tags: ruby libgosu
# **********Processing***********
# Code: ['class Tile &lt; Chingu::GameObject\n  trait :bounding_box\n  trait :collision_detection\n\n  def initialize (x, y, w, h, opts={})\n    super opts\n    @area = Chingu::Rect.new(x,y,w,h)\n  end\n\n  def collision_at?(x, y)\n    @area.collide_point?(x,y)\n  end       \nend\n']
# **Question Procesing**
# Step1: <p>I'm trying to make a GameObject which does not use Gosu::Image but Chingu::Rect.
# That's my class by omitting all unimportant methods</p>
#
# <pre></pre>
#
# <p>However collision detection is not working. Does anybody know how to tell the bounding_box to use a specific Rectangle and not an Image?</p>
#
# Step2: b" I'm trying to make a GameObject which does not use Gosu::Image but Chingu::Rect.\nThat's my class by omitting all unimportant methods \n\n  \n\n However collision detection is not working. Does anybody know how to tell the bounding_box to use a specific Rectangle and not an Image? \n"
# Step3: b'Creating GameObject of variable size using Chingu' b" I'm trying to make a GameObject which does not use Gosu::Image but Chingu::Rect.\nThat's my class by omitting all unimportant methods \n\n  \n\n However collision detection is not working. Does anybody know how to tell the bounding_box to use a specific Rectangle and not an Image? \n"
# Step4: b Creating GameObject of variable size using Chingu b I m trying to make a GameObject which does not use Gosu Image but Chingu Rect nThat s my class by omitting all unimportant methods n n n n However collision detection is not working Does anybody know how to tell the bounding box to use a specific Rectangle and not an Image n
# Step5: creat gameobject variabl size use chingu tri make gameobject use gosu imag chingu rect nthat class omit unimport method howev collis detect work anybodi know tell bound box use specif rectangl imag
# ****Processing Done*******
# Result:
# ('creat gameobject variabl size use chingu tri make gameobject use gosu imag chingu rect nthat class omit unimport method howev collis detect work anybodi know tell bound box use specif rectangl imag', "['class Tile &lt; Chingu::GameObject\\n  trait :bounding_box\\n  trait :collision_detection\\n\\n  def initialize (x, y, w, h, opts={})\\n    super opts\\n    @area = Chingu::Rect.new(x,y,w,h)\\n  end\\n\\n  def collision_at?(x, y)\\n    @area.collide_point?(x,y)\\n  end       \\nend\\n']", 'ruby libgosu', 619, 197, 1)
# number of questions completed= 6
# Title: ZeroMQ: multiple remote (LAN) publishers
# Question: <p>I have a basic ZeroMQ scenario consisting of two publishers and a subscriber. This has been working fine on a local computer until I decided to separate all process in different computers within my LAN. This is how I'm creating the ZeroMQ sockets (simplified Python code):</p>
#
# <p>(Subscriber process running on machine with IP <code>192.168.1.52</code>)</p>
#
# <p>Publisher code (common for both publishers):</p>
#
# <pre><code>context = zmq.Context()
# self.pub_socket = context.socket(zmq.PUB)
# self.pub_socket.connect("tcp://192.168.1.52:5556")
# </code></pre>
#
# <p>Subscriber code:</p>
#
# <pre><code>context = zmq.Context()
# self.sub_socket = context.socket(zmq.SUB)
# self.sub_socket.bind("tcp://192.168.1.52:5556")
# self.sub_socket.setsockopt(zmq.SUBSCRIBE, "")
# </code></pre>
#
# <p>I've tried entering <code>tcp://127.0.0.1:5556</code> as the binding <code>address:port</code> for the subscriber but that makes no difference.</p>
#
# Tags: python zeromq
# **********Processing***********
# Code: ['192.168.1.52', 'context = zmq.Context()\nself.pub_socket = context.socket(zmq.PUB)\nself.pub_socket.connect("tcp://192.168.1.52:5556")\n', 'context = zmq.Context()\nself.sub_socket = context.socket(zmq.SUB)\nself.sub_socket.bind("tcp://192.168.1.52:5556")\nself.sub_socket.setsockopt(zmq.SUBSCRIBE, "")\n', 'tcp://127.0.0.1:5556', 'address:port']
# **Question Procesing**
# Step1: <p>I have a basic ZeroMQ scenario consisting of two publishers and a subscriber. This has been working fine on a local computer until I decided to separate all process in different computers within my LAN. This is how I'm creating the ZeroMQ sockets (simplified Python code):</p>
#
# <p>(Subscriber process running on machine with IP )</p>
#
# <p>Publisher code (common for both publishers):</p>
#
# <pre></pre>
#
# <p>Subscriber code:</p>
#
# <pre></pre>
#
# <p>I've tried entering  as the binding  for the subscriber but that makes no difference.</p>
#
# Step2: b" I have a basic ZeroMQ scenario consisting of two publishers and a subscriber. This has been working fine on a local computer until I decided to separate all process in different computers within my LAN. This is how I'm creating the ZeroMQ sockets (simplified Python code): \n\n (Subscriber process running on machine with IP ) \n\n Publisher code (common for both publishers): \n\n  \n\n Subscriber code: \n\n  \n\n I've tried entering  as the binding  for the subscriber but that makes no difference. \n"
# Step3: b'ZeroMQ: multiple remote (LAN) publishers' b" I have a basic ZeroMQ scenario consisting of two publishers and a subscriber. This has been working fine on a local computer until I decided to separate all process in different computers within my LAN. This is how I'm creating the ZeroMQ sockets (simplified Python code): \n\n (Subscriber process running on machine with IP ) \n\n Publisher code (common for both publishers): \n\n  \n\n Subscriber code: \n\n  \n\n I've tried entering  as the binding  for the subscriber but that makes no difference. \n"
# Step4: b ZeroMQ multiple remote LAN publishers b I have a basic ZeroMQ scenario consisting of two publishers and a subscriber This has been working fine on a local computer until I decided to separate all process in different computers within my LAN This is how I m creating the ZeroMQ sockets simplified Python code n n Subscriber process running on machine with IP n n Publisher code common for both publishers n n n n Subscriber code n n n n I ve tried entering as the binding for the subscriber but that makes no difference n
# Step5: zeromq multipl remot lan publish basic zeromq scenario consist two publish subscrib work fine local comput decid separ process differ comput within lan creat zeromq socket simplifi python code subscrib process run machin ip publish code common publish subscrib code tri enter bind subscrib make differ
# ****Processing Done*******
# Result:
# ('zeromq multipl remot lan publish basic zeromq scenario consist two publish subscrib work fine local comput decid separ process differ comput within lan creat zeromq socket simplifi python code subscrib process run machin ip publish code common publish subscrib code tri enter bind subscrib make differ', '[\'192.168.1.52\', \'context = zmq.Context()\\nself.pub_socket = context.socket(zmq.PUB)\\nself.pub_socket.connect("tcp://192.168.1.52:5556")\\n\', \'context = zmq.Context()\\nself.sub_socket = context.socket(zmq.SUB)\\nself.sub_socket.bind("tcp://192.168.1.52:5556")\\nself.sub_socket.setsockopt(zmq.SUBSCRIBE, "")\\n\', \'tcp://127.0.0.1:5556\', \'address:port\']', 'python zeromq', 961, 301, 1)
# number of questions completed= 7
# Title: Java. Regular Expression. How Parse?
# Question: <p>As input parameters I can have two types of String:</p>
#
# <pre><code>codeName=SomeCodeName&amp;codeValue=SomeCodeValue
# </code></pre>
#
# <p>or  </p>
#
# <pre><code>codeName=SomeCodeName
# </code></pre>
#
# <p>without <code>codeValue</code>.</p>
#
# <p><code>codeName</code> and <code>codeValue</code> are the keys.</p>
#
# <p>How can I use regular expression to return the key's values? In this example it would return only <code>SomeCodeName</code> and <code>SomeCodeValue</code>.</p>
#
# Tags: java regex
# **********Processing***********
# Code: ['codeName=SomeCodeName&amp;codeValue=SomeCodeValue\n', 'codeName=SomeCodeName \n', 'codeValue', 'codeName', 'codeValue', 'SomeCodeName', 'SomeCodeValue']
# **Question Procesing**
# Step1: <p>As input parameters I can have two types of String:</p>
#
# <pre></pre>
#
# <p>or  </p>
#
# <pre></pre>
#
# <p>without .</p>
#
# <p> and  are the keys.</p>
#
# <p>How can I use regular expression to return the key's values? In this example it would return only  and .</p>
#
# Step2: b" As input parameters I can have two types of String: \n\n  \n\n or   \n\n  \n\n without . \n\n  and  are the keys. \n\n How can I use regular expression to return the key's values? In this example it would return only  and . \n"
# Step3: b'Java. Regular Expression. How Parse?' b" As input parameters I can have two types of String: \n\n  \n\n or   \n\n  \n\n without . \n\n  and  are the keys. \n\n How can I use regular expression to return the key's values? In this example it would return only  and . \n"
# Step4: b Java Regular Expression How Parse b As input parameters I can have two types of String n n n n or n n n n without n n and are the keys n n How can I use regular expression to return the key s values In this example it would return only and n
# Step5: java regular express pars input paramet two type string without key use regular express return key valu exampl would return
# ****Processing Done*******
# Result:
# ('java regular express pars input paramet two type string without key use regular express return key valu exampl would return', "['codeName=SomeCodeName&amp;codeValue=SomeCodeValue\\n', 'codeName=SomeCodeName \\n', 'codeValue', 'codeName', 'codeValue', 'SomeCodeName', 'SomeCodeValue']", 'java regex', 508, 123, 1)
# number of questions completed= 8
# Title: LESS compile error on individual bootstrap components
# Question: <p>I am a little bit confused.  I am trying to use Node.js with lessc to compile my application which includes parts of bootstrap.  I want to be able to pick bits and pieces of bootstrap for what I need since I won't be using all of it.  When I import <code>bootstrap.less</code> everything compiles perfectly.  But if I import just <code>reset.less</code> or <code>buttons.less</code> I get: <code>TypeError: Cannot call method 'charAt' of undefined</code>.  What is going on here?</p>
#
# <p><strong>My Folder Setup</strong></p>
#
# <pre><code>less/
#     application.less
#     bootstrap/
#         bootstrap.less
#         reset.less
#         buttons.less
#         etc...
# </code></pre>
#
# <p><strong>application.less</strong></p>
#
# <p>Everything compiles fine when I have <code>@import 'bootstrap/bootstrap'</code>
# I get the above error when I have <code>@import 'bootstrap/reset'</code></p>
#
# <p>And I have tried adding .less to the end of the file name as well, same results.
# I found online that less version 1.3.0 should fix this, but that is the version I am using.</p>
#
# <p>Any help will be greatly appreciated.</p>
#
# Tags: node.js twitter-bootstrap less server-side
# **********Processing***********
# Code: ['bootstrap.less', 'reset.less', 'buttons.less', "TypeError: Cannot call method 'charAt' of undefined", 'less/\n    application.less\n    bootstrap/\n        bootstrap.less\n        reset.less\n        buttons.less\n        etc...\n', "@import 'bootstrap/bootstrap'", "@import 'bootstrap/reset'"]
# **Question Procesing**
# Step1: <p>I am a little bit confused.  I am trying to use Node.js with lessc to compile my application which includes parts of bootstrap.  I want to be able to pick bits and pieces of bootstrap for what I need since I won't be using all of it.  When I import  everything compiles perfectly.  But if I import just  or  I get: .  What is going on here?</p>
#
# <p><strong>My Folder Setup</strong></p>
#
# <pre></pre>
#
# <p><strong>application.less</strong></p>
#
# <p>Everything compiles fine when I have
# I get the above error when I have </p>
#
# <p>And I have tried adding .less to the end of the file name as well, same results.
# I found online that less version 1.3.0 should fix this, but that is the version I am using.</p>
#
# <p>Any help will be greatly appreciated.</p>
#
# Step2: b" I am a little bit confused.  I am trying to use Node.js with lessc to compile my application which includes parts of bootstrap.  I want to be able to pick bits and pieces of bootstrap for what I need since I won't be using all of it.  When I import  everything compiles perfectly.  But if I import just  or  I get: .  What is going on here? \n\n  My Folder Setup  \n\n  \n\n  application.less  \n\n Everything compiles fine when I have \nI get the above error when I have  \n\n And I have tried adding .less to the end of the file name as well, same results.\nI found online that less version 1.3.0 should fix this, but that is the version I am using. \n\n Any help will be greatly appreciated. \n"
# Step3: b'LESS compile error on individual bootstrap components' b" I am a little bit confused.  I am trying to use Node.js with lessc to compile my application which includes parts of bootstrap.  I want to be able to pick bits and pieces of bootstrap for what I need since I won't be using all of it.  When I import  everything compiles perfectly.  But if I import just  or  I get: .  What is going on here? \n\n  My Folder Setup  \n\n  \n\n  application.less  \n\n Everything compiles fine when I have \nI get the above error when I have  \n\n And I have tried adding .less to the end of the file name as well, same results.\nI found online that less version 1.3.0 should fix this, but that is the version I am using. \n\n Any help will be greatly appreciated. \n"
# Step4: b LESS compile error on individual bootstrap components b I am a little bit confused I am trying to use Node js with lessc to compile my application which includes parts of bootstrap I want to be able to pick bits and pieces of bootstrap for what I need since I won t be using all of it When I import everything compiles perfectly But if I import just or I get What is going on here n n My Folder Setup n n n n application less n n Everything compiles fine when I have nI get the above error when I have n n And I have tried adding less to the end of the file name as well same results nI found online that less version should fix this but that is the version I am using n n Any help will be greatly appreciated n
# Step5: less compil error individu bootstrap compon littl bit confus tri use node js lessc compil applic includ part bootstrap want abl pick bit piec bootstrap need sinc use import everyth compil perfect import get go folder setup applic less everyth compil fine ni get error tri ad less end file name well result ni found onlin less version fix version use help great appreci
# ****Processing Done*******
# Result:
# ('less compil error individu bootstrap compon littl bit confus tri use node js lessc compil applic includ part bootstrap want abl pick bit piec bootstrap need sinc use import everyth compil perfect import get go folder setup applic less everyth compil fine ni get error tri ad less end file name well result ni found onlin less version fix version use help great appreci', '[\'bootstrap.less\', \'reset.less\', \'buttons.less\', "TypeError: Cannot call method \'charAt\' of undefined", \'less/\\n    application.less\\n    bootstrap/\\n        bootstrap.less\\n        reset.less\\n        buttons.less\\n        etc...\\n\', "@import \'bootstrap/bootstrap\'", "@import \'bootstrap/reset\'"]', 'node.js twitter-bootstrap less server-side', 1157, 368, 1)
# number of questions completed= 9
# Avg. length of questions(Title+Body) before processing: 1376
# Avg. length of questions(Title+Body) after processing: 264
# Percent of questions containing code: 66
# Time taken to run this cell : 0:00:00.038714

# %% [markdown]
# <h1>4. Machine Learning Models </h1>

# %% [markdown]
# <h2> 4.1 Converting tags for multilabel problems </h2>

# %% [markdown]
# <table>
# <tr>
# <th>X</th><th>y1</th><th>y2</th><th>y3</th><th>y4</th>
# </tr>
# <tr>
# <td>x1</td><td>0</td><td>1</td><td>1</td><td>0</td>
# </tr>
# <tr>
# <td>x1</td><td>1</td><td>0</td><td>0</td><td>0</td>
# </tr>
# <tr>
# <td>x1</td><td>0</td><td>1</td><td>0</td><td>0</td>
# </tr>
# </table>

# %%
# Install the PyDrive wrapper & import libraries.
# This only needs to be done once per notebook.
# !pip install -U -q PyDrive
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

# Authenticate and create the PyDrive client.
# This only needs to be done once per notebook.
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# Download a file based on its file ID.
#
# A file ID looks like: https://drive.google.com/open?id=1-wQdz3-SLJeEsLK95yFOG5DhIiP6lupn
file_id = '1-wQdz3-SLJeEsLK95yFOG5DhIiP6lupn'
downloaded = drive.CreateFile({'id': file_id})
downloaded.GetContentFile('Processed.db')
# print('Downloaded content "{}"'.format(downloaded.GetContentString()))
# Out:
#      |████████████████████████████████| 993kB 6.9MB/s
#   Building wheel for PyDrive (setup.py) ... done

# %%
#Taking 1 Million entries to a dataframe.
write_db = 'Processed.db'
if os.path.isfile(write_db):
    conn_r = sqlite3.connect(write_db)
    if conn_r is not None:
        preprocessed_data = pd.read_sql_query("""SELECT question, Tags FROM QuestionsProcessed""", conn_r)
conn_r.commit()
conn_r.close()

# %%
preprocessed_data.head()
# Out:
#                                             question                                               tags
# 0  wp multisit network plugin fail see class load...  php plugin-development theme-development multi...
# 1  error miss core name path solr use queri solr ...                                          java solr
# 2  get session sign usernam tri get usernam sign ...                                          php mysql
# 3  font color html email gmail know use inlin css...                               css gmail html-email
# 4  sqlite databas squirrel relat sqlite databas c...         sql database sqlite relations squirrel-sql

# %%
# binary='true' will give a binary vectorizer
vectorizer = CountVectorizer(tokenizer = lambda x: x.split(), binary='true')
multilabel_y = vectorizer.fit_transform(preprocessed_data['tags'])

# %%
print(multilabel_y[333])
print("Shape: ", multilabel_y.shape)
vectorizer.get_feature_names()[90:95]
# Out:
#   (0, 16000)	1
#   (0, 32519)	1
# Shape:  (999999, 35408)
# ['2d-games', '2d-vector', '2phase-commit', '2tb', '2to3']

# %%
preprocessed_data.shape
# Out:
# (999999, 2)

# %% [markdown]
# __ We will sample the number of tags instead considering all of them (due to limitation of computing power) __

# %%
###TESTING###
t = multilabel_y.sum(axis=0).tolist()[0]
sorted_tags_i = sorted(range(len(t)), key=lambda i: t[i], reverse=True)
print(t)
print(len(t))
print(max(t))
print(sorted_tags_i)
print(t[3708])
# Out:
# [5, 2, 6, 36, 20, 2, 14, 1, 2, 36, 10, 8, 1, 3546, 13, 3, 4, 2, 27039, 4, 67, 379, 11, 891, 1195, 2, 1, 156, 111, 10, 13, 57, 3, 21, 4, 1, 26, 9, 25, 5, 5, 1, 7, 4, 6, 4, 15, 25, 2, 7, 2, 7, 3, 1, 4, 4, 13, 4, 9, 13, 2, 3, 2, 1, 4, 1, 6, 20, 6, 1, 5, 2, 8, 1, 3, 4, 2, 2, 6, 510, 887, 157, 1, 5, 1, 5, 362, 86, 1, 1, 28, 2, 2, 1, 1, 4, 36, 2, 97, 12, 1, 17, 2, 8, 34, 104, 4, 1, 97, 199, 2, 4, 5, 6, 7, 5, 998, 8, 9, 12, 5, 15, 10, 3, 1, 7, 3, 2, 1, 4, 13, 2, 13, 9, 31, 119, 3, 17, 2, 14, 5, 18, 1, 14, 4, 26, 54, 56, 1, 5, 7, 6, 1, 4, 3, 10, 3, 24, 4, 2, 7, 16, 2, 5, 2, 1, 446, 464, 3, 5, 1, 1, 2, 56, 3, 3, 1, 2, 1, 49, 6, 15, 6, 13, 1, 2, 14, 17, 2, 1, 41, 9, 4, 3, 48, 1, 28, 5, 61, 2, 8, 1, 1, 8, 45, 1, 13, 4, 8, 13, 65, 1, 1, 1, 2, 65, 1, 2, 12, 4, 8, 27, 10, 75, 8, 1, 21, 1, 1, 1, 4, 1, 35, 2, 1, 5, 4, 14, 3, 12, 7, 3, 72, 51, 165, 39, 7, 125, 3, 1608, 2, 268, 14, 7, 1, 1, 9, 33, 4, 74, 18, 1, 12, 3, 3, 3, 1, 6, 14, 16, 5, 20, 15, 215, 16, 37, 16, 34, 3, 1, 96, 2, 6, 7, 82, 1, 91, 5, 4, 4, 18, 53, 35, 13, 3, 2, 19, 118, 220, 94, 12, 8, 263, 7, 1, 56, 10, 1, 13, 4, 10, 1, 2, 234, 4, 95, 16, 2, 40, 34, 17, 1, 5, 10, 10, 3, 1, 11, 6, 22, 1, 25, 14, 1, 12, 45, 8, 2, 3, 89, 3, 28, 13, 1, 19, 1, 266, 4, 26, 1, 1, 3, 30, 2, 5, 19, 104, 2, 5, 1, 9, 7, 7, 33, 2, 46, 2, 1, 1, 368, 2, 42, 2, 3, 278, 4, 21, 5, 4, 9, 4, 53, 153, 181, 2, 8, 3, 5, 31, 45, 1186, 2, 271, 4506, 44, 7, 1, 19, 3, 90, 4, 2, 23, 91, 1, 1, 1772, 1, 8, 1, 1, 1, 3, 7, 1, 7, 3, 6, 147, 3, 3, 1, 13, 2, 29, 2, 41, 231, 6, 2, 18, 2, 7, 2, 1812, 1, 2, 1, 1, 25, 41, 20, 12, 35, 55, 1, 3, 375, 1, 3, 30, 22, 984, 7, 3, 20, 11, 20, 1, 6, 8, 1, 26, 1, 3, 117, 3, 6, 3, 2, 7, 1, 2, 6, 43, 2, 7, 1, 1, 5, 2, 16, 18, 25, 27, 2, 83, 1, 6, 21, 9, 289, 1, 1, 2, 218, 10, 22, 1, 13, 229, 39, 2, 3, 3, 17, 14, 232, 6, 14, 58, 2, 3, 12, 6, 3, 6, 1, 4, 28, 111, 1, 3, 67, 8, 3, 41, 2, 52, 8, 3, 1, 6, 3, 3, 4, 141, 22, 20, 6, 1, 114, 7, 8, 4, 2, 6, 4, 50, 37, 1, 9, 5, 2, 46, 35, 1, 58, 4, 3, 7, 27, 1, 11, 15, 2, 9, 28, 2, 4, 3, 1, 430, 18, 13, 2, 33, 1, 2, 1, 10, 239, 1, 142, 266, 4, 212, 7, 929, 50, 571, 56, 5, 9, 1, 1, 7, 2, 1, 2, 2, 4, 15, 3, 9, 1, 8, 5, 30, 5, 10, 82, 25, 1, 5, 2, 163, 19, 1, 61, 2, 2, 56, 5, 3, 3, 3, 2, 18, 3, 2, 3, 3, 6, 2, 8, 2, 1, 4, 100, 3, 97, 5, 20, 56, 9, 4, 3, 1, 173, 1, 2, 1, 24, 6, 5, 6, 5, 9, 54, 40, 1, 6, 8, 1, 26, 1, 6, 91, 45, 6, 6, 17, 1, 9, 34, 34, 1, 5, 3, 2, 89, 9, 2, 6, 1, 287, 1, 1, 2, 5, 7, 2, 1, 1, 19, 3, 2, 26, 20, 26, 1, 2, 3, 131, 31, 33, 2, 1, 16, 7, 2, 2, 5, 7, 3, 5, 18, 58, 3, 3, 9, 10, 182, 201, 13, 5, 85, 13, 8, 2, 4, 247, 7, 10, 4, 1, 2, 12, 6, 1, 1, 8, 1, 11, 15, 2, 11, 1, 33, 3, 5, 9, 4, 10, 2, 926, 5, 1, 26, 3, 4, 7, 5, 8, 35, 45, 7, 17, 17, 1, 1, 1, 166, 10742, 10, 1, 1, 9, 4, 8, 19, 17, 23, 2, 59, 4, 1, 257, 30, 4, 5, 10, 5, 1, 83, 1, 5, 30, 12, 1, 1, 5, 129, 1, 1, 1, 2, 93, 1, 173, 8, 20, 48, 6, 1, 1, 1, 3, 9, 7, 5, 12, 4, 1, 237, 162, 4, 41, 12, 3, 3, 2, 141, 13, 51, 970, 4, 54, 1, 13, 678, 10, 26, 2, 175, 2, 484, 5, 2, 5153, 7, 26, 3, 3, 9, 18, 649, 280, 1, 1, 1, 12, 14, 3, 2, 7, 4, 96, 411, 4, 5, 1, 5, 1, 27, 5, 14, 6, 4, 1, 2, 19, 5, 81, 31, 1, 3, 1, 12, 8, 2, 1, 11, 9, 115, 11, 6, 1, 23, 6, 2, 30, 2, 3, 1, 58, 37, 6, 76, 30, 2, 3, 1, 38, 1, 2, 29, 2, 41, 4, 12, 20, 6, 10, 1, 6, 1, 5, 78, 25, 16, 4, 3, 1, 1, 5, 2, 6, 1, 5, 13, 2, 2, 3, 2, 2, 1, 2, 3, 2, 9, 2, 286, 32, 4, 2, 14, 89, 6, 18, 61, 79, 1413, 3, 14, 9, 35, 26, 3, 8, 4, 12, 2, 14, 81, 3, 26, 860, 38, 1, 69, 9, 31, 2, 7, 1072, 1, 4, 44, 21, 9, 15, 130, 2, 10, 4, 42, 2, 1, 4, 3, 3, 4, 1, 39, 32, 23, 2, 3, 4, 1, 40, 8, 4, 9, 4, 6, 90, 13, 21, 11, 113, 2, 4, 25, 3, 7, 1, 22, 14, 3, 1, 1086, 1, 33, 2, 12, 127, 85, 3, 15, 225, 1, 23, 1, 10, 6, 318, 2, 1, 2, 206, 1, 55804, 2, 6, 2, 23, 35, 32, 16, 4, 2, 52, 15, 2, 323, 1, 377, 55, 13, 42, 89, 160, 11, 11, 5, 33, 22, 2, 13, 172, 29, 625, 26, 16, 1, 12, 5, 9, 13, 38, 24, 81, 140, 30, 235, 30, 182, 3, 9, 11, 16, 8, 113, 209, 38, 18, 4, 2, 29, 42, 25, 72, 12, 19, 1, 1, 4, 56, 37, 10, 23, 3, 2, 165, 905, 23, 9, 1, 20, 47, 4, 10, 50, 5 ...
# 35408
# 78698
# [3708, 15283, 22986, 15356, 1054, 15745, 3717, 24529, 14924, 1891, 19819, 13445, 18, 14865, 21186, 28842, 6358, 26503, 17078, 3707, 34006, 26485, 28880, 34498, 34861, 774, 6833, 25553, 1909, 34742, 8013, 1828, 32772, 34014, 21996, 8938, 10072, 15970, 26505, 29462, 22779, 19705, 34202, 31865, 33160, 1913, 13501, 14065, 20289, 13314, 34365, 27118, 33491, 11153, 850, 2679, 11971, 24855, 33637, 21847, 33153, 17054, 28884, 22795, 24971, 28736, 27886, 1417, 14907, 393, 29928, 10790, 4949, 4944, 9727, 13147, 9175, 9374, 10436, 1498, 17105, 15860, 10846, 27709, 1481, 20530, 24737, 7401, 28961, 13, 14723, 12264, 31607, 10694, 13541, 21509, 18061, 32248, 32279, 7211, 4657, 5079, 11442, 29862, 23625, 12243, 28882, 32687, 16000, 22432, 28348, 14016, 30555, 34107, 33960, 12343, 27054, 34170, 19147, 19756, 9687, 35271, 18348, 15950, 26762, 32053, 34701, 27645, 29048, 17699, 2187, 33157, 32779, 27450, 32430, 12219, 10095, 31209, 5294, 7523, 1166, 2134, 22657, 3711, 7516, 32747, 25948, 15757, 30226, 20384, 23371, 15298, 3815, 32918, 8208, 6389, 28465, 21764, 7004, 17151, 33130, 33012, 18089, 16986, 25454, 12790, 8581, 9751, 30653, 3839, 19392, 12745, 18021, 35059, 17373, 8330, 34139, 11746, 3793, 25324, 23695, 19002, 33570, 14882, 7039, 21118, 22945, 29067, 21601, 17471, 15821, 27447, 18923, 34019, 23429, 6849, 12980, 17066, 5978, 11631, 14410, 12492, 27156, 4219, 22833, 1320, 3463, 16633, 1597, 23574, 20378, 3667, 434, 23963, 7993, 21570, 406, 12547, 13983, 9296, 18371, 7470, 15705, 27335, 6727, 28770, 7194, 12627, 14098, 14028, 10512, 5621, 9167, 29399, 28293, 30685, 8757, 5924, 249, 32869, 11038, 15658, 3232, 15837, 17389, 32561, 20183, 6461, 10013, 1910, 1724, 2575, 23916, 8162, 6396, 15364, 25534, 17639, 1158, 31720, 3054, 34137, 11798, 25219, 26955, 29996, 26970, 34999, 1974, 963, 6718, 19778, 6811, 15477, 17685, 24247, 2460, 12346, 3959, 32194, 11396, 31016, 27397, 2528, 9291, 29279, 1915, 33556, 31724, 32959, 10471, 9744, 1366, 30410, 14943, 23984, 10585, 8559, 5265, 5180, 30045, 2939, 13113, 14555, 2044, 25116, 25419, 13972, 15670, 14490, 13649, 15952, 21948, 16237, 12919, 12960, 21605, 32076, 24, 26366, 18533, 16495, 390, 27199, 30589, 2702, 5424, 12519, 25789, 32497, 11713, 24178, 27677, 31832, 32639, 11056, 9375, 5252, 32055, 32447, 33794, 11269, 18369, 6923, 17891, 5568, 2704, 12672, 1033, 1887, 7702, 12850, 32397, 5230, 986, 33785, 8085, 34166, 14689, 9752, 11142, 28413, 12645, 34269, 32821, 12036, 22376, 14728, 10605, 32787, 6932, 27318, 3728, 25503, 14209, 5449, 18402, 18412, 2250, 21094, 27139, 21539, 6234, 29356, 3555, 4387, 4445, 32080, 116, 24536, 34750, 15731, 14886, 30991, 452, 32591, 27890, 27026, 22544, 5147, 18075, 7360, 19593, 22042, 836, 9530, 21018, 19029, 24085, 33313, 15306, 30795, 30280, 33165, 34141, 15844, 18076, 16098, 29855, 13877, 2535, 29575, 29228, 14893, 28242, 588, 17292, 5120, 21053, 756, 32082, 4421, 26439, 8453, 26621, 4069, 12267, 15421, 11471, 32777, 13739, 1127, 8289, 18547, 18613, 26360, 14836, 5720, 7455, 3843, 15260, 5270, 23, 31059, 33833, 80, 8482, 33088, 29552, 26506, 23314, 6153, 19426, 31529, 18091, 10050, 32028, 34817, 16957, 17376, 8966, 5683, 19095, 24541, 31398, 13035, 23035, 2316, 978, 20044, 14717, 23874, 4818, 35188, 22698, 33077, 26443, 5412, 4962, 11072, 14526, 25513, 30736, 2122, 3297, 5659, 7358, 1825, 2426, 25925, 30312, 28964, 19192, 3175, 8312, 18717, 7680, 16360, 29062, 18423, 34973, 16481, 3009, 12531, 6323, 35173, 25765, 31999, 22526, 6435, 10387, 34891, 9651, 23269, 16672, 16528, 29426, 17084, 19984, 22268, 9420, 11481, 1303, 1275, 14625, 1174, 16895, 17038, 6987, 14718, 17564, 22596, 34397, 10723, 34149, 5877, 7630, 1593, 31473, 11826, 11477, 23067, 33731, 18238, 20991, 9126, 14878, 2909, 10897, 11786, 19215, 22355, 30021, 9762, 14612, 7804, 16201, 20683, 25890, 5763, 1572, 10632, 16244, 3888, 8254, 8584, 27301, 5326, 12602, 6056, 10934, 12138, 3867, 20271, 33711, 17234, 30843, 5432, 4959, 1198, 7717, 5947, 14663, 26522, 6250, 19184, 28886, 20903, 26333, 22000, 12464, 14 ...
# 78698

# %%
multilabel_yn=multilabel_y[:,sorted_tags_i[:500]]
print(multilabel_yn.shape)   ## Shape (999999, 500) all rows but top 500 tag columns
multilabel_y[:, 3708]       ##for  3708th column

x= multilabel_yn.sum(axis=1)    ##(999999, 1)
print(x.shape)
print(np.count_nonzero(x==0))
# Out:
# (999999, 500)
# (999999, 1)
# 100135

# %%
def tags_to_choose(n):
    t = multilabel_y.sum(axis=0).tolist()[0]   ##column wise sum of tags
    sorted_tags_i = sorted(range(len(t)), key=lambda i: t[i], reverse=True)  ##(index value) giving index of t in dec order where the number of tag is maximum
    multilabel_yn=multilabel_y[:,sorted_tags_i[:n]] ## taking all the rows from multilabel_y where the top n column tags are present the
#     print(multilabel_yn)
    return multilabel_yn

def questions_explained_fn(n):
    multilabel_yn = tags_to_choose(n)
    x= multilabel_yn.sum(axis=1)    ##(999999, 1)   row wise sum of all the n tag columns
    return (np.count_nonzero(x==0))   ##number of zero values along an axis (0 means column)

# %%
questions_explained = []
total_tags=multilabel_y.shape[1]
total_qs=preprocessed_data.shape[0]
for i in range(500, total_tags, 100):
    questions_explained.append(np.round(((total_qs-questions_explained_fn(i))/total_qs)*100,3))

# %%
questions_explained[:10]
# Out:
# [89.986, 91.223, 92.152, 92.972, 93.691, 94.208, 94.548, 94.92, 95.251, 95.552]

# %%
fig, ax = plt.subplots()
ax.plot(questions_explained)
xlabel = list(500+np.array(range(-50,450,50))*50)
ax.set_xticklabels(xlabel)
plt.xlabel("Number of tags")
plt.ylabel("Number Questions coverd partially")
plt.grid()
plt.show()
# you can choose any number of tags based on your computing power, minimun is 500(it covers 90% of the tags)
print("with ",5500,"tags we are covering ",questions_explained[50],"% of questions")
# Out:
# with  5500 tags we are covering  99.037 % of questions

# %%
multilabel_yx = tags_to_choose(5500)
print("number of questions that are not covered :", questions_explained_fn(5500),"out of ", total_qs)
# Out:
# number of questions that are not covered : 9631 out of  999999

# %%
print("Number of tags in sample :", multilabel_y.shape[1])
print("number of tags taken :", multilabel_yx.shape[1],"(",(multilabel_yx.shape[1]/multilabel_y.shape[1])*100,"%)")
# Out:
# Number of tags in sample : 35408
# number of tags taken : 5500 ( 15.53321283325802 %)

# %% [markdown]
# __ We consider top 15% tags which covers  99% of the questions __

# %% [markdown]
# <h2>4.2 Split the data into test and train (80:20) </h2>

# %%
total_size=preprocessed_data.shape[0]
train_size=int(0.80*total_size)
print("Total size:", total_size)
print("Train size: ", train_size)

x_train=preprocessed_data.head(train_size)
x_test=preprocessed_data.tail(total_size - train_size)
print("Test shape: ", x_test.shape)

y_train = multilabel_yx[0:train_size,:]
y_test = multilabel_yx[train_size:total_size,:]

# print(x_train)
# print(y_test)
# Out:
# Total size: 999999
# Train size:  799999
# Test shape:  (200000, 2)

# %%
print("Number of data points in train data :", y_train.shape)
print("Number of data points in test data :", y_test.shape)
# Out:
# Number of data points in train data : (799999, 5500)
# Number of data points in test data : (200000, 5500)

# %% [markdown]
# <h2>4.3 Featurizing data </h2>

# %%
start = datetime.now()
vectorizer = TfidfVectorizer(min_df=0.00009, max_features=200000, smooth_idf=True, norm="l2", \
                             tokenizer = lambda x: x.split(), sublinear_tf=False, ngram_range=(1,3))
x_train_multilabel = vectorizer.fit_transform(x_train['question'])
x_test_multilabel = vectorizer.transform(x_test['question'])
print("Time taken to run this cell :", datetime.now() - start)
# Out:
# Time taken to run this cell : 0:09:36.065406

# %%
print("Dimensions of train data X:",x_train_multilabel.shape, "Y :",y_train.shape)
print("Dimensions of test data X:",x_test_multilabel.shape,"Y:",y_test.shape)
# Out:
# Dimensions of train data X: (799999, 88170) Y : (799999, 5500)
# Dimensions of test data X: (200000, 92495) Y: (200000, 5500)

# %%
# https://www.analyticsvidhya.com/blog/2017/08/introduction-to-multi-label-classification/
#https://stats.stackexchange.com/questions/117796/scikit-multi-label-classification
# classifier = LabelPowerset(GaussianNB())
"""
from skmultilearn.adapt import MLkNN
classifier = MLkNN(k=21)

# train
classifier.fit(x_train_multilabel, y_train)

# predict
predictions = classifier.predict(x_test_multilabel)
print(accuracy_score(y_test,predictions))
print(metrics.f1_score(y_test, predictions, average = 'macro'))
print(metrics.f1_score(y_test, predictions, average = 'micro'))
print(metrics.hamming_loss(y_test,predictions))

"""
# we are getting memory error because the multilearn package
# is trying to convert the data into dense matrix
# ---------------------------------------------------------------------------
#MemoryError                               Traceback (most recent call last)
#<ipython-input-170-f0e7c7f3e0be> in <module>()
#----> classifier.fit(x_train_multilabel, y_train)

# %% [markdown]
# <h2> 4.4 Applying Logistic Regression with OneVsRest Classifier </h2>

# %%
# this will be taking so much time try not to run it, download the lr_with_equal_weight.pkl file and use to predict
# This takes about 6-7 hours to run.
classifier = OneVsRestClassifier(SGDClassifier(loss='log', alpha=0.00001, penalty='l1'), n_jobs=-1)
classifier.fit(x_train_multilabel, y_train)
predictions = classifier.predict(x_test_multilabel)

print("accuracy :",metrics.accuracy_score(y_test,predictions))
print("macro f1 score :",metrics.f1_score(y_test, predictions, average = 'macro'))
print("micro f1 scoore :",metrics.f1_score(y_test, predictions, average = 'micro'))
print("hamming loss :",metrics.hamming_loss(y_test,predictions))
print("Precision recall report :\n",metrics.classification_report(y_test, predictions))

# %%
from sklearn.externals import joblib
joblib.dump(classifier, 'lr_with_equal_weight.pkl')

# %% [markdown]
# <h2> 4.5 Modeling with less data points (0.5M data points) and more weight to title and 500 tags only. </h2>

# %%
sql_create_table = """CREATE TABLE IF NOT EXISTS QuestionsProcessed (question text NOT NULL, code text, tags text, words_pre integer, words_post integer, is_code integer);"""
create_database_table("Titlemoreweight.db", sql_create_table)

# %%
# http://www.sqlitetutorial.net/sqlite-delete/
# https://stackoverflow.com/questions/2279706/select-random-row-from-a-sqlite-table

read_db = 'train_no_dup.db'
write_db = 'Titlemoreweight.db'
train_datasize = 400000
if os.path.isfile(read_db):
    conn_r = create_connection(read_db)
    if conn_r is not None:
        reader =conn_r.cursor()
        # for selecting first 0.5M rows
        reader.execute("SELECT Title, Body, Tags From no_dup_train LIMIT 500001;")
        # for selecting random points
        #reader.execute("SELECT Title, Body, Tags From no_dup_train ORDER BY RANDOM() LIMIT 500001;")

if os.path.isfile(write_db):
    conn_w = create_connection(write_db)
    if conn_w is not None:
        tables = checkTableExists(conn_w)
        writer =conn_w.cursor()
        if tables != 0:
            writer.execute("DELETE FROM QuestionsProcessed WHERE 1")
            print("Cleared All the rows")

# %% [markdown]
# <h3> 4.5.1 Preprocessing of questions </h3>

# %% [markdown]
# <ol>
#     <li> Separate Code from Body </li>
#     <li> Remove Spcial characters from Question title and description (not in code)</li>
#     <li> <b> Give more weightage to title : Add title three times to the question </b> </li>
#
#     <li> Remove stop words (Except 'C') </li>
#     <li> Remove HTML Tags </li>
#     <li> Convert all the characters into small letters </li>
#     <li> Use SnowballStemmer to stem the words </li>
# </ol>

# %%
#http://www.bernzilla.com/2008/05/13/selecting-a-random-row-from-an-sqlite-table/
start = datetime.now()
preprocessed_data_list=[]
reader.fetchone()
questions_with_code=0
len_pre=0
len_post=0
questions_proccesed = 0
for row in reader:

    is_code = 0

    title, question, tags = row[0], row[1], str(row[2])

    if '<code>' in question:
        questions_with_code+=1
        is_code = 1
    x = len(question)+len(title)
    len_pre+=x

    code = str(re.findall(r'<code>(.*?)</code>', question, flags=re.DOTALL))

    question=re.sub('<code>(.*?)</code>', '', question, flags=re.MULTILINE|re.DOTALL)
    question=striphtml(question.encode('utf-8'))

    title=title.encode('utf-8')

    # adding title three time to the data to increase its weight
    # add tags string to the training data

    question=str(title)+" "+str(title)+" "+str(title)+" "+question

#     if questions_proccesed<=train_datasize:
#         question=str(title)+" "+str(title)+" "+str(title)+" "+question+" "+str(tags)
#     else:
#         question=str(title)+" "+str(title)+" "+str(title)+" "+question

    question=re.sub(r'[^A-Za-z0-9#+.\-]+',' ',question)
    words=word_tokenize(str(question.lower()))

    #Removing all single letter and and stopwords from question exceptt for the letter 'c'
    question=' '.join(str(stemmer.stem(j)) for j in words if j not in stop_words and (len(j)!=1 or j=='c'))

    len_post+=len(question)
    tup = (question,code,tags,x,len(question),is_code)
    questions_proccesed += 1
    writer.execute("insert into QuestionsProcessed(question,code,tags,words_pre,words_post,is_code) values (?,?,?,?,?,?)",tup)
    if (questions_proccesed%100000==0):
        print("number of questions completed=",questions_proccesed)

no_dup_avg_len_pre=(len_pre*1.0)/questions_proccesed
no_dup_avg_len_post=(len_post*1.0)/questions_proccesed

print( "Avg. length of questions(Title+Body) before processing: %d"%no_dup_avg_len_pre)
print( "Avg. length of questions(Title+Body) after processing: %d"%no_dup_avg_len_post)
print ("Percent of questions containing code: %d"%((questions_with_code*100.0)/questions_proccesed))

print("Time taken to run this cell :", datetime.now() - start)

# %%
# never forget to close the conections or else we will end up with database locks
conn_r.commit()
conn_w.commit()
conn_r.close()
conn_w.close()

# %% [markdown]
# __ Sample quesitons after preprocessing of data __

# %%
if os.path.isfile(write_db):
    conn_r = create_connection(write_db)
    if conn_r is not None:
        reader =conn_r.cursor()
        reader.execute("SELECT question From QuestionsProcessed LIMIT 10")
        print("Questions after preprocessed")
        print('='*100)
        reader.fetchone()
        for row in reader:
            print(row)
            print('-'*100)
conn_r.commit()
conn_r.close()

# %% [markdown]
# __ Saving Preprocessed data to a Database __

# %%
#Taking 0.5 Million entries to a dataframe.
write_db = 'Titlemoreweight.db'
if os.path.isfile(write_db):
    conn_r = create_connection(write_db)
    if conn_r is not None:
        preprocessed_data = pd.read_sql_query("""SELECT question, Tags FROM QuestionsProcessed""", conn_r)
conn_r.commit()
conn_r.close()

# %%
preprocessed_data.head()

# %%
print("number of data points in sample :", preprocessed_data.shape[0])
print("number of dimensions :", preprocessed_data.shape[1])

# %% [markdown]
# __ Converting string Tags to multilable output variables __

# %%
vectorizer = CountVectorizer(tokenizer = lambda x: x.split(), binary='true')
multilabel_y = vectorizer.fit_transform(preprocessed_data['tags'])

# %% [markdown]
# __ Selecting 500 Tags __

# %%
questions_explained = []
total_tags=multilabel_y.shape[1]
total_qs=preprocessed_data.shape[0]
for i in range(500, total_tags, 100):
    questions_explained.append(np.round(((total_qs-questions_explained_fn(i))/total_qs)*100,3))

# %%
fig, ax = plt.subplots()
ax.plot(questions_explained)
xlabel = list(500+np.array(range(-50,450,50))*50)
ax.set_xticklabels(xlabel)
plt.xlabel("Number of tags")
plt.ylabel("Number Questions coverd partially")
plt.grid()
plt.show()
# you can choose any number of tags based on your computing power, minimun is 500(it covers 90% of the tags)
print("with ",5500,"tags we are covering ",questions_explained[50],"% of questions")
print("with ",500,"tags we are covering ",questions_explained[0],"% of questions")

# %%
# we will be taking 500 tags
multilabel_yx = tags_to_choose(500)
print("number of questions that are not covered :", questions_explained_fn(500),"out of ", total_qs)

# %%
x_train=preprocessed_data.head(train_datasize)
x_test=preprocessed_data.tail(preprocessed_data.shape[0] - 400000)

y_train = multilabel_yx[0:train_datasize,:]
y_test = multilabel_yx[train_datasize:preprocessed_data.shape[0],:]

# %%
print("Number of data points in train data :", y_train.shape)
print("Number of data points in test data :", y_test.shape)

# %% [markdown]
# <h3> 4.5.2 Featurizing data with TfIdf vectorizer </h3>

# %%
start = datetime.now()
vectorizer = TfidfVectorizer(min_df=0.00009, max_features=200000, smooth_idf=True, norm="l2", \
                             tokenizer = lambda x: x.split(), sublinear_tf=False, ngram_range=(1,3))
x_train_multilabel = vectorizer.fit_transform(x_train['question'])
x_test_multilabel = vectorizer.transform(x_test['question'])
print("Time taken to run this cell :", datetime.now() - start)

# %%
print("Dimensions of train data X:",x_train_multilabel.shape, "Y :",y_train.shape)
print("Dimensions of test data X:",x_test_multilabel.shape,"Y:",y_test.shape)

# %% [markdown]
# <h3> 4.5.3 Applying Logistic Regression with OneVsRest Classifier </h3>

# %%
start = datetime.now()
classifier = OneVsRestClassifier(SGDClassifier(loss='log', alpha=0.00001, penalty='l1'), n_jobs=-1)
classifier.fit(x_train_multilabel, y_train)
predictions = classifier.predict (x_test_multilabel)


print("Accuracy :",metrics.accuracy_score(y_test, predictions))
print("Hamming loss ",metrics.hamming_loss(y_test,predictions))


precision = precision_score(y_test, predictions, average='micro')
recall = recall_score(y_test, predictions, average='micro')
f1 = f1_score(y_test, predictions, average='micro')

print("Micro-average quality numbers")
print("Precision: {:.4f}, Recall: {:.4f}, F1-measure: {:.4f}".format(precision, recall, f1))

precision = precision_score(y_test, predictions, average='macro')
recall = recall_score(y_test, predictions, average='macro')
f1 = f1_score(y_test, predictions, average='macro')

print("Macro-average quality numbers")
print("Precision: {:.4f}, Recall: {:.4f}, F1-measure: {:.4f}".format(precision, recall, f1))

print (metrics.classification_report(y_test, predictions))
print("Time taken to run this cell :", datetime.now() - start)

# %%
joblib.dump(classifier, 'lr_with_more_title_weight.pkl')

# %%
start = datetime.now()
classifier_2 = OneVsRestClassifier(LogisticRegression(penalty='l1'), n_jobs=-1)
classifier_2.fit(x_train_multilabel, y_train)
predictions_2 = classifier_2.predict(x_test_multilabel)
print("Accuracy :",metrics.accuracy_score(y_test, predictions_2))
print("Hamming loss ",metrics.hamming_loss(y_test,predictions_2))


precision = precision_score(y_test, predictions_2, average='micro')
recall = recall_score(y_test, predictions_2, average='micro')
f1 = f1_score(y_test, predictions_2, average='micro')

print("Micro-average quality numbers")
print("Precision: {:.4f}, Recall: {:.4f}, F1-measure: {:.4f}".format(precision, recall, f1))

precision = precision_score(y_test, predictions_2, average='macro')
recall = recall_score(y_test, predictions_2, average='macro')
f1 = f1_score(y_test, predictions_2, average='macro')

print("Macro-average quality numbers")
print("Precision: {:.4f}, Recall: {:.4f}, F1-measure: {:.4f}".format(precision, recall, f1))

print (metrics.classification_report(y_test, predictions_2))
print("Time taken to run this cell :", datetime.now() - start)

# %% [markdown]
# <h1> 5. Assignments </h1>

# %% [markdown]
# <ol>
#     <li> Use bag of words upto 4 grams and compute the micro f1 score with Logistic regression(OvR) </li>
#     <li> Perform hyperparam tuning on alpha (or lambda) for Logistic regression to improve the performance using GridSearch  </li>
#     <li> Try OneVsRestClassifier  with Linear-SVM (SGDClassifier with loss-hinge)</li>
# </ol>
